# %%
import AlGDock.BindingPMF_plots
from AlGDock.BindingPMF_plots import *
import os, shutil, glob

phases = ['NAMD_Gas', 'NAMD_OBC']

self = AlGDock.BindingPMF_plots.BPMF_plots(\
  dir_dock='dock', dir_cool='cool',\
  ligand_tarball='prmtopcrd/ligand.tar.gz', \
  ligand_database='ligand.db', \
  forcefield='prmtopcrd/gaff.dat', \
  ligand_prmtop='ligand.prmtop', \
  ligand_inpcrd='ligand.trans.inpcrd', \
  ligand_mol2='ligand.mol2', \
  ligand_rb='ligand.rb', \
  receptor_tarball='prmtopcrd/receptor.tar.gz', \
  receptor_prmtop='receptor.prmtop', \
  receptor_inpcrd='receptor.trans.inpcrd', \
  receptor_fixed_atoms='receptor.pdb', \
  complex_tarball='prmtopcrd/complex.tar.gz', \
  complex_prmtop='complex.prmtop', \
  complex_inpcrd='complex.trans.inpcrd', \
  complex_fixed_atoms='complex.pdb', \
  score = 'prmtopcrd/anchor_and_grow_scored.mol2', \
  pose=-1, \
  rmsd=True, \
  dir_grid='grids', \
  protocol='Adaptive', cool_therm_speed=0.5, dock_therm_speed=0.5, \
  T_HIGH=600.0, T_SIMMIN=300.0, T_TARGET=300.0, \
  sampler='HMC', fraction_CD=0.5, CD_steps_per_trial=10, \
  MCMC_moves=1, \
  sampling_importance_resampling = True, \
  solvation = 'Desolvated', \
  seeds_per_state=10, steps_per_seed=200, darts_per_seed=0, \
  sweeps_per_cycle=25, attempts_per_sweep=100, \
  steps_per_sweep=100, darts_per_sweep=0, \
  cool_repX_cycles=3, dock_repX_cycles=4, \
  site='Sphere', site_center=[1.74395, 1.74395, 1.74395], \
  site_max_R=0.6, \
  site_density=10., \
  phases=phases, \
  cores=-1, \
  random_seed=-1, \
  max_time=240)
# Out:
# ###########
# # AlGDock #
# ###########
# Molecular docking with adaptively scaled alchemical interaction grids
#
# in /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.py
# last modified Mon Jan 16 16:04:34 2017
#
# using 4/4 available cores
# using random number seed of -1
#   no progress information for dock
#   no progress information for cool
#
# *** Directories ***
#   start: /Users/dminh/Installers/AlGDock-0.0.1/Example
#   cool: /Users/dminh/Installers/AlGDock-0.0.1/Example/cool
#   dock: /Users/dminh/Installers/AlGDock-0.0.1/Example/dock
#
# >>> Decompressing tarballs
# looking for:
#   complex.trans.inpcrd
#   complex.pdb
#   ligand.mol2
#   receptor.trans.inpcrd
#   ligand.trans.inpcrd
#   ligand.prmtop
#   ligand.db
#   receptor.pdb
#   complex.prmtop
#   ligand.rb
#   receptor.prmtop
#   and frcmod files
# reading prmtopcrd/complex.tar.gz
#   extracted complex.pdb
#   extracted complex.prmtop
#   extracted complex.trans.inpcrd
# reading prmtopcrd/receptor.tar.gz
#   extracted receptor.pdb
#   extracted receptor.prmtop
#   extracted receptor.trans.inpcrd
# reading prmtopcrd/ligand.tar.gz
#   extracted ligand.db
#   extracted /Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod
#   extracted ligand.mol2
#   extracted ligand.prmtop
#   extracted ligand.rb
#   extracted ligand.trans.inpcrd
#
# *** Files ***
#   ligand_database: dock/ligand.db
#   forcefield: prmtopcrd/gaff.dat
#   frcmodList: ['/Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod']
#   tarball:
#     L: prmtopcrd/ligand.tar.gz
#     R: prmtopcrd/receptor.tar.gz
#     RL: prmtopcrd/complex.tar.gz
#   prmtop:
#     L: dock/ligand.prmtop
#     R: dock/receptor.prmtop
#     RL: dock/complex.prmtop
#   inpcrd:
#     L: dock/ligand.trans.inpcrd
#     R: dock/receptor.trans.inpcrd
#     RL: dock/complex.trans.inpcrd
#   mol2:
#     L: dock/ligand.mol2
#   rb:
#     L: dock/ligand.rb
#   fixed_atoms:
#     R: dock/receptor.pdb
#     RL: dock/complex.pdb
#   grids:
#     LJr: grids/LJr.nc
#     LJa: grids/LJa.nc
#     ELE: grids/pbsa.nc
#   score: prmtopcrd/anchor_and_grow_scored.mol2
#   dir_cool: cool
#           DOES NOT EXIST
#
# >>> Setting up the simulation
#   considering a residue named "iga" as the ligand
#
# *** Simulation parameters and constants ***
#
# for cool:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 3
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 3.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#
# for dock:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 4
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 20.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   site: Sphere
#   site_center: array([ 1.74395,  1.74395,  1.74395])
#   site_max_R: 0.6
#   site_density: 10.0
#   pose: -1
#   k_pose: 200.0
#   MCMC_moves: 1
#   rmsd: True

# %%
#   from AlGDock.ForceFields.OBC.OBC import OBCForceField
#   FF = OBCForceField(self._FNs['prmtop']['L'], self.molecule.prmtop_atom_order,self.molecule.inv_prmtop_atom_order)
#   self.universe.setForceField(FF)
#   print self.universe.energyTerms()
#   (e,forces) = self.universe.energyAndGradients()
#   print forces.array

#   FF.set_strength(0.1)
#   self.universe.setForceField(FF)
#   print self.universe.energyTerms()
#   (e2,forces2) = self.universe.energyAndGradients()
#   print forces2.array

# %%
self._run('all')
# Out:
# >>> Initial warming
#     starting at Mon, 16 Jan 2017 16:12:34 +0000
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/simtk/openmm/app/internal/amber_file_parser.py:1010: UserWarning: Non-optimal GB parameters detected for GB model OBC2
#   'model %s' % gbmodel)
#   minimized 223 configurations in 22.22 s
#   the first 10 energies are:
#   -305.30, -301.76, -303.33, -276.99, -296.15, -294.98, -292.05, -300.81, -302.06, -303.02
#   keeping 223 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 0 duplicated
#   ramped temperature from 20 to 300 K
#   changing energy from -308 to -223 kcal/mol
#
#   drew 10 configurations at 300 K in 0.17 s
#   Sampler 74/100=0.74 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.652e-02
#
#   drew 10 configurations at 330 K in 0.17 s
#   Sampler 67/100=0.67 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.382e-02
#   the estimated repX acceptance rate is 0.75
#
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   drew 10 configurations at 374 K in 0.17 s
#   Sampler 51/100=0.51 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.238e-02
#   the estimated repX acceptance rate is 0.58
#
#   drew 10 configurations at 402 K in 0.17 s
#   Sampler 67/100=0.67 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.387e-02
#   the estimated repX acceptance rate is 0.80
#
#   drew 10 configurations at 444 K in 0.16 s
#   Sampler 54/100=0.54 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.288e-02
#   the estimated repX acceptance rate is 0.59
#
#   drew 10 configurations at 491 K in 0.17 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.134e-02
#   the estimated repX acceptance rate is 0.60
#
#   drew 10 configurations at 545 K in 0.17 s
#   Sampler 53/100=0.53 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.304e-02
#   the estimated repX acceptance rate is 0.65
#
#   drew 10 configurations at 593 K in 0.17 s
#   Sampler 53/100=0.53 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.099e-02
#   the estimated repX acceptance rate is 0.78
#
#   drew 10 configurations at 600 K in 0.16 s
#   Sampler 57/100=0.57 (0.3 s);
#   dt=3.00 fs; tL_tensor=7.406e-03
#   the estimated repX acceptance rate is 0.96
#
#   reversing replicas, samples, and protocol
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
# Elapsed time for initial warming of 9 states: 26.40 s
#
# >>> Replica exchange for cooling
#     starting at Mon, 16 Jan 2017 16:13:00 +0000 GMT
#
#   saving 4 configurations in cycle 1 in 2.05 s (tau_ac=7.282)
#   Sampler 151/225=0.67 (4.1 s); repX t 0.2 s
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   calculated cooling free energy of -39.44 RT using cycles 0 to 0
#   calculated cooling free energy of -38.11 RT using cycles 1 to 1
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: xtol=0.000000 is too small, no further improvement in the approximate
#   solution is possible.
#   warnings.warn(msg, RuntimeWarning)
#   saving 6 configurations in cycle 2 in 2.01 s (tau_ac=5.3967)
#   Sampler 143/225=0.64 (4.0 s); repX t 0.2 s
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   calculated cooling free energy of -38.40 RT using cycles 1 to 2
#
# Elapsed time for 2 cycles of replica exchange was 5.13 s
#
# >>> Postprocessing
#     starting at Mon, 16 Jan 2017 16:13:05 +0000
#
#   postprocessed cool, state 8, cycle 0, LNAMD_Gas in 0.23 s
#   postprocessed cool, state 8, cycle 0, LNAMD_OBC in 0.23 s
#   postprocessed cool, state 8, cycle 1, LNAMD_Gas in 0.22 s
#   postprocessed cool, state 8, cycle 1, LNAMD_OBC in 0.23 s
#   postprocessed cool, state 8, cycle 2, LNAMD_Gas in 0.17 s
#   postprocessed cool, state 8, cycle 2, LNAMD_OBC in 0.16 s
#   an average of 0.035727 s per LNAMD_OBC snapshot
#   an average of 0.035804 s per LNAMD_Gas snapshot
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
# Elapsed time for postprocessing was 0.91 s
#
# >>> Ligand free energy calculations
#     starting at Mon, 16 Jan 2017 16:13:06 +0000
#
#   calculated NAMD_Gas solvation free energy of 146.72 RT using cycles 0 to 0
#   calculated NAMD_Gas solvation free energy of 152.33 RT using cycles 1 to 1
#   calculated NAMD_Gas solvation free energy of 147.16 RT using cycles 1 to 2
#   calculated NAMD_OBC solvation free energy of 68.639 RT using cycles 0 to 0
#   calculated NAMD_OBC solvation free energy of 68.328 RT using cycles 1 to 1
#   calculated NAMD_OBC solvation free energy of 68.625 RT using cycles 1 to 2
#   wrote to f_L.pkl.gz
#
# Elapsed time for free energy calculation: 0.03 s
#
# >>> Initial docking
#     starting at Mon, 16 Jan 2017 16:13:06 +0000
#
#   LJr grid loaded from LJr.nc in 0.37 s
#   LJa grid loaded from LJa.nc in 0.16 s
#   ELE grid loaded from pbsa.nc in 0.02 s
#   minimized 3 configurations in 0.28 s
#   the first 3 energies are:
#   -445.29, -406.11, -401.03
#   keeping 3 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 0 duplicated
#   ramped temperature from 20 to 300 K
#   changing energy from -445 to -353 kcal/mol
#
#   sLJr grid loaded from LJr.nc in 0.31 s
#   sELE grid loaded from pbsa.nc in 0.03 s
#   drew 10 configurations with progress 1.000000e+00 in 0.58 s
#   Sampler 68/100=0.68 (0.6 s);
#   dt=3.00 fs, tL_tensor=3.031e+01
#   drew 10 configurations with progress 9.835024e-01 in 0.32 s
#   Sampler 67/100=0.67 (0.9 s);
#   dt=3.00 fs, tL_tensor=2.417e+01
#   the estimated repX acceptance rate is 0.91
#
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   drew 10 configurations with progress 9.628127e-01 in 0.28 s
#   Sampler 53/100=0.53 (0.8 s);
#   dt=3.00 fs, tL_tensor=2.877e+01
#   the estimated repX acceptance rate is 0.81
#
#   drew 10 configurations with progress 9.454345e-01 in 0.29 s
#   Sampler 64/100=0.64 (0.8 s);
#   dt=3.00 fs, tL_tensor=2.797e+01
#   the estimated repX acceptance rate is 0.89
#
#   drew 10 configurations with progress 9.275589e-01 in 0.29 s
#   Sampler 68/100=0.68 (0.8 s);
#   dt=3.00 fs, tL_tensor=2.463e+01
#   the estimated repX acceptance rate is 0.88
#
#   drew 10 configurations with progress 9.072575e-01 in 0.29 s
#   Sampler 69/100=0.69 (0.8 s);
#   dt=3.00 fs, tL_tensor=2.014e+01
#   the estimated repX acceptance rate is 0.91
#
#   drew 10 configurations with progress 8.824276e-01 in 0.34 s
#   Sampler 71/100=0.71 (0.9 s);
#   dt=3.00 fs, tL_tensor=1.499e+01
#   the estimated repX acceptance rate is 0.88
#
#   drew 10 configurations with progress 8.490611e-01 in 0.29 s
#   Sampler 68/100=0.68 (0.8 s);
#   dt=3.00 fs, tL_tensor=2.110e+01
#   the estimated repX acceptance rate is 0.90
#
#   drew 10 configurations with progress 8.253611e-01 in 0.41 s
#   Sampler 58/100=0.58 (1.1 s);
#   dt=3.00 fs, tL_tensor=1.295e+01
#   the estimated repX acceptance rate is 0.87
#
#   drew 10 configurations with progress 7.867367e-01 in 0.37 s
#   Sampler 60/100=0.60 (1.0 s);
#   dt=3.00 fs, tL_tensor=1.319e+01
#   the estimated repX acceptance rate is 0.86
#
#   drew 10 configurations with progress 7.488243e-01 in 0.37 s
#   Sampler 65/100=0.65 (1.0 s);
#   dt=3.00 fs, tL_tensor=1.344e+01
#   the estimated repX acceptance rate is 0.89
#
#   drew 10 configurations with progress 7.116218e-01 in 0.39 s
#   Sampler 61/100=0.61 (1.1 s);
#   dt=3.00 fs, tL_tensor=8.439e+00
#   the estimated repX acceptance rate is 0.88
#
#   drew 10 configurations with progress 6.523715e-01 in 0.31 s
#   Sampler 47/100=0.47 (0.8 s);
#   dt=3.00 fs, tL_tensor=1.150e+01
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations with progress 5.980089e-01 in 0.34 s
#   Sampler 64/100=0.64 (0.9 s);
#   dt=3.00 fs, tL_tensor=6.087e+00
#   the estimated repX acceptance rate is 0.85
#
#   drew 10 configurations with progress 5.158729e-01 in 0.37 s
#   Sampler 60/100=0.60 (1.0 s);
#   dt=3.00 fs, tL_tensor=3.865e+00
#   the estimated repX acceptance rate is 0.87
#
#   drew 10 configurations with progress 3.865228e-01 in 0.36 s
#   Sampler 59/100=0.59 (1.0 s);
#   dt=3.00 fs, tL_tensor=4.635e+00
#   the estimated repX acceptance rate is 0.80
#
#   drew 10 configurations with progress 2.786490e-01 in 0.23 s
#   Sampler 44/100=0.44 (0.6 s);
#   dt=3.00 fs, tL_tensor=8.758e+00
#   the estimated repX acceptance rate is 0.60
#
#   drew 10 configurations with progress 2.215581e-01 in 0.25 s
#   Sampler 69/100=0.69 (0.6 s);
#   dt=3.00 fs, tL_tensor=7.075e+00
#   the estimated repX acceptance rate is 0.65
#
#   drew 10 configurations with progress 1.508887e-01 in 0.26 s
#   Sampler 62/100=0.62 (0.7 s);
#   dt=3.00 fs, tL_tensor=1.195e+01
#   the estimated repX acceptance rate is 0.80
#
#   drew 10 configurations with progress 1.090361e-01 in 0.26 s
#   Sampler 64/100=0.64 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.205e+01
#   the estimated repX acceptance rate is 0.54
#
#   drew 10 configurations with progress 8.636458e-02 in 0.22 s
#   ExternalMC 0/50=0.00 (0.0 s); Sampler 59/100=0.59 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.870e+01
#   the estimated repX acceptance rate is 0.87
#
#   drew 10 configurations with progress 5.961975e-02 in 0.22 s
#   ExternalMC 1/50=0.02 (0.0 s); Sampler 59/100=0.59 (0.5 s);
#   dt=3.00 fs, tL_tensor=3.519e+01
#   the estimated repX acceptance rate is 0.50
#
#   drew 10 configurations with progress 4.541068e-02 in 0.26 s
#   ExternalMC 2/50=0.04 (0.0 s); Sampler 80/100=0.80 (0.6 s);
#   dt=3.00 fs, tL_tensor=3.086e+01
#   the estimated repX acceptance rate is 0.86
#
#   drew 10 configurations with progress 2.920752e-02 in 0.26 s
#   ExternalMC 8/50=0.16 (0.0 s); Sampler 67/100=0.67 (0.6 s);
#   dt=3.00 fs, tL_tensor=7.237e+01
#   the estimated repX acceptance rate is 0.43
#
#   drew 10 configurations with progress 2.229860e-02 in 0.23 s
#   ExternalMC 6/50=0.12 (0.0 s); Sampler 64/100=0.64 (0.5 s);
#   dt=3.00 fs, tL_tensor=7.081e+01
#   the estimated repX acceptance rate is 0.76
#
#   drew 10 configurations with progress 1.523729e-02 in 0.26 s
#   ExternalMC 7/50=0.14 (0.0 s); Sampler 67/100=0.67 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.163e+02
#   the estimated repX acceptance rate is 0.79
#
#   drew 10 configurations with progress 1.093930e-02 in 0.26 s
#   ExternalMC 8/50=0.16 (0.0 s); Sampler 63/100=0.63 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.172e+02
#   the estimated repX acceptance rate is 0.82
#
#   drew 10 configurations with progress 6.673269e-03 in 0.24 s
#   ExternalMC 11/50=0.22 (0.0 s); Sampler 62/100=0.62 (0.5 s);
#   dt=3.00 fs, tL_tensor=2.031e+02
#   the estimated repX acceptance rate is 0.56
#
#   drew 10 configurations with progress 4.211147e-03 in 0.25 s
#   ExternalMC 11/50=0.22 (0.0 s); Sampler 68/100=0.68 (0.5 s);
#   dt=3.00 fs, tL_tensor=2.399e+02
#   the estimated repX acceptance rate is 0.83
#
#   drew 10 configurations with progress 2.126946e-03 in 0.28 s
#   ExternalMC 10/50=0.20 (0.0 s); Sampler 63/100=0.63 (0.6 s);
#   dt=3.00 fs, tL_tensor=3.158e+02
#   the estimated repX acceptance rate is 0.60
#
#   drew 10 configurations with progress 5.436434e-04 in 0.22 s
#   ExternalMC 9/50=0.18 (0.0 s); Sampler 62/100=0.62 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.193e+03
#   rejected new state with low estimated acceptance rate of 3.57e-01
#   drew 10 configurations with progress 8.603040e-04 in 0.25 s
#   ExternalMC 15/50=0.30 (0.0 s); Sampler 66/100=0.66 (0.6 s);
#   dt=3.00 fs, tL_tensor=4.664e+02
#   the estimated repX acceptance rate is 0.72
#
#   drew 10 configurations with progress 0.000000e+00 in 0.19 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 51/100=0.51 (0.4 s);
#   dt=3.00 fs, tL_tensor=4.553e+04
#   rejected new state with low estimated acceptance rate of 1.62e-03
#   drew 10 configurations with progress 2.734205e-06 in 0.22 s
#   ExternalMC 46/50=0.92 (0.0 s); Sampler 69/100=0.69 (0.5 s);
#   dt=3.00 fs, tL_tensor=4.967e+04
#   rejected new state with low estimated acceptance rate of 6.41e-05
#   drew 10 configurations with progress 1.742482e-04 in 0.22 s
#   ExternalMC 15/50=0.30 (0.0 s); Sampler 73/100=0.73 (0.5 s);
#   dt=3.00 fs, tL_tensor=2.325e+03
#   the estimated repX acceptance rate is 0.41
#
#   drew 10 configurations with progress 0.000000e+00 in 0.26 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 68/100=0.68 (0.6 s);
#   dt=3.00 fs, tL_tensor=3.584e+04
#   rejected new state with low estimated acceptance rate of 1.02e-01
#   drew 10 configurations with progress 2.196127e-06 in 0.22 s
#   ExternalMC 44/50=0.88 (0.0 s); Sampler 59/100=0.59 (0.5 s);
#   dt=3.00 fs, tL_tensor=5.119e+04
#   rejected new state with low estimated acceptance rate of 3.44e-03
#   drew 10 configurations with progress 3.660653e-05 in 0.22 s
#   ExternalMC 23/50=0.46 (0.0 s); Sampler 65/100=0.65 (0.5 s);
#   dt=3.00 fs, tL_tensor=2.949e+04
#   rejected new state with low estimated acceptance rate of 3.66e-01
#   drew 10 configurations with progress 6.413486e-05 in 0.33 s
#   ExternalMC 20/50=0.40 (0.0 s); Sampler 66/100=0.66 (0.8 s);
#   dt=3.00 fs, tL_tensor=1.484e+04
#   the estimated repX acceptance rate is 0.60
#
#   drew 10 configurations with progress 3.044236e-05 in 0.30 s
#   ExternalMC 26/50=0.52 (0.0 s); Sampler 61/100=0.61 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.690e+04
#   the estimated repX acceptance rate is 0.55
#
#   drew 10 configurations with progress 1.185518e-05 in 0.23 s
#   ExternalMC 44/50=0.88 (0.0 s); Sampler 64/100=0.64 (0.5 s);
#   dt=3.00 fs, tL_tensor=3.598e+04
#   the estimated repX acceptance rate is 0.46
#
#   drew 10 configurations with progress 0.000000e+00 in 0.19 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 71/100=0.71 (0.4 s);
#   dt=3.00 fs, tL_tensor=3.920e+04
#   the estimated repX acceptance rate is 0.77
#
#   reversing replicas, samples, and protocol
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
# Elapsed time for initial docking of 35 states: 16.49 s
#
# >>> Reinitializing replica exchange configurations
#   minimized 3 configurations in 0.29 s
#   the first 3 energies are:
#   -445.29, -406.11, -401.03
#   keeping 35 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 32 duplicated
#
# >>> Replica exchange for docking
#     starting at Mon, 16 Jan 2017 16:13:23 +0000 GMT
#
#   saving 12 configurations in cycle 1 in 10.43 s (tau_ac=10.176)
#   ExternalMC 552/2000=0.28 (1.3 s); Sampler 384/875=0.44 (29.7 s); repX t 1.1 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   wrote to f_RL.pkl.gz
#   calculated grid scaling free energy of -85.91 RT using cycles 1 to 1
#   wrote to f_RL.pkl.gz
#   inserted state between 6.4135e-05 and 0.00017425 at 0.00011919
#   to improve acceptance rate from 0.29911 to 0.46499
#   wrote to f_RL.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   saving 12 configurations in cycle 2 in 10.05 s (tau_ac=10.284)
#   ExternalMC 640/2125=0.30 (1.3 s); Sampler 482/900=0.54 (28.1 s); repX t 1.1 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   calculated grid scaling free energy of -79.96 RT using cycles 1 to 2
#   wrote to f_RL.pkl.gz
#   inserted state between 0.00017425 and 0.0008603 at 0.00051728
#   to improve acceptance rate from 0.38236 to 0.49491
#   wrote to f_RL.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   saving 12 configurations in cycle 3 in 11.35 s (tau_ac=10.245)
#   ExternalMC 635/2250=0.28 (1.5 s); Sampler 542/925=0.59 (31.7 s); repX t 1.3 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   calculated grid scaling free energy of -77.90 RT using cycles 1 to 3
#   wrote to f_RL.pkl.gz
#
# Elapsed time for 3 cycles of replica exchange was 36.04 s
#
# >>> Postprocessing
#     starting at Mon, 16 Jan 2017 16:13:59 +0000
#
#   postprocessed dock, state 36, cycle 0, LNAMD_OBC in 0.27 s
#   postprocessed dock, state 36, cycle 0, LNAMD_Gas in 0.28 s
#   postprocessed dock, state 36, cycle 1, LNAMD_Gas in 0.27 s
#   postprocessed dock, state 36, cycle 1, LNAMD_OBC in 0.29 s
#   postprocessed original, state 0, cycle 0, RNAMD_Gas in 0.77 s
#   postprocessed dock, state 36, cycle 2, LNAMD_OBC in 0.27 s
#   postprocessed dock, state 36, cycle 2, LNAMD_Gas in 0.31 s
#   postprocessed dock, state 36, cycle 3, LNAMD_Gas in 0.28 s
#   postprocessed dock, state 36, cycle 3, LNAMD_OBC in 0.27 s
#   postprocessed dock, state 36, cycle 0, RLNAMD_Gas in 0.75 s
#   postprocessed dock, state 36, cycle 1, RLNAMD_Gas in 0.80 s
#   postprocessed dock, state 36, cycle 2, RLNAMD_Gas in 0.70 s
#   postprocessed original, state 0, cycle 0, RNAMD_OBC in 3.08 s
#   postprocessed dock, state 36, cycle 3, RLNAMD_Gas in 0.70 s
#   postprocessed dock, state 36, cycle 0, RLNAMD_OBC in 19.75 s
#   postprocessed dock, state 36, cycle 1, RLNAMD_OBC in 23.07 s
#   postprocessed dock, state 36, cycle 2, RLNAMD_OBC in 22.67 s
#   postprocessed dock, state 36, cycle 3, RLNAMD_OBC in 22.30 s
#   an average of 0.06473 s per RLNAMD_Gas snapshot
#   an average of 3.0822 s per RNAMD_OBC snapshot
#   an average of 0.76985 s per RNAMD_Gas snapshot
#   an average of 0.023951 s per LNAMD_OBC snapshot
#   an average of 0.02478 s per LNAMD_Gas snapshot
#   an average of 1.9111 s per RLNAMD_OBC snapshot
#   wrote to dock_progress.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
# Elapsed time for postprocessing was 26.63 s
#   calculated grid scaling free energy of -77.51 RT using cycles 0 to 0
#   calculated grid scaling free energy of -86.12 RT using cycles 1 to 1
#   calculated grid scaling free energy of -79.83 RT using cycles 1 to 2
#   calculated NAMD_Gas binding PMF of -204.24 RT with cycles 0 to 0
#   calculated NAMD_Gas binding PMF of -209.18 RT with cycles 1 to 1
#   calculated NAMD_Gas binding PMF of -209.43 RT with cycles 1 to 2
#   calculated NAMD_Gas binding PMF of -209.08 RT with cycles 1 to 3
#   calculated NAMD_OBC binding PMF of -55.88 RT with cycles 0 to 0
#   calculated NAMD_OBC binding PMF of -60.3 RT with cycles 1 to 1
#   calculated NAMD_OBC binding PMF of -60.516 RT with cycles 1 to 2
#   calculated NAMD_OBC binding PMF of -60.161 RT with cycles 1 to 3
#   wrote to f_RL.pkl.gz
#
# Elapsed time for binding PMF estimation: 0.55 s
