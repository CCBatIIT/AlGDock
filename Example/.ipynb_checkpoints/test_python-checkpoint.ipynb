# %%
import AlGDock.BindingPMF_plots
from AlGDock.BindingPMF_plots import *
import os, shutil, glob

phases = ['NAMD_Gas', 'NAMD_OBC']

self = AlGDock.BindingPMF_plots.BPMF_plots(\
  dir_dock='dock', dir_cool='cool',\
  ligand_tarball='prmtopcrd/ligand.tar.gz', \
  ligand_database='ligand.db', \
  forcefield='prmtopcrd/gaff2.dat', \
  ligand_prmtop='ligand.prmtop', \
  ligand_inpcrd='ligand.trans.inpcrd', \
  ligand_mol2='ligand.mol2', \
  ligand_rb='ligand.rb', \
  receptor_tarball='prmtopcrd/receptor.tar.gz', \
  receptor_prmtop='receptor.prmtop', \
  receptor_inpcrd='receptor.trans.inpcrd', \
  receptor_fixed_atoms='receptor.pdb', \
  complex_tarball='prmtopcrd/complex.tar.gz', \
  complex_prmtop='complex.prmtop', \
  complex_inpcrd='complex.trans.inpcrd', \
  complex_fixed_atoms='complex.pdb', \
  score = 'prmtopcrd/anchor_and_grow_scored.mol2', \
  pose=-1, \
  rmsd=True, \
  dir_grid='grids', \
  protocol='Adaptive', cool_therm_speed=5.0, dock_therm_speed=0.5, \
  T_HIGH=600.0, T_SIMMIN=300.0, T_TARGET=300.0, \
  sampler='HMC', \
  MCMC_moves=1, \
  sampling_importance_resampling = True, \
  solvation = 'Fractional', \
  seeds_per_state=10, steps_per_seed=200, darts_per_seed=0, \
  sweeps_per_cycle=25, attempts_per_sweep=100, \
  steps_per_sweep=100, darts_per_sweep=0, \
  cool_repX_cycles=3, dock_repX_cycles=4, \
  site='Sphere', site_center=[1.74395, 1.74395, 1.74395], \
  site_max_R=0.6, \
  site_density=10., \
  phases=phases, \
  cores=-1, \
  random_seed=-1, \
  max_time=240)
# Out:
# ###########
# # AlGDock #
# ###########
# Molecular docking with adaptively scaled alchemical interaction grids
#
# in /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.py
# last modified Mon Jan 16 16:04:34 2017
#
# using 4/4 available cores
# using random number seed of -1
#   no progress information for dock
#   no progress information for cool
#
# *** Directories ***
#   start: /Users/dminh/Installers/AlGDock-0.0.1/Example
#   cool: /Users/dminh/Installers/AlGDock-0.0.1/Example/cool
#   dock: /Users/dminh/Installers/AlGDock-0.0.1/Example/dock
#
# >>> Decompressing tarballs
# looking for:
#   complex.trans.inpcrd
#   complex.pdb
#   ligand.mol2
#   receptor.trans.inpcrd
#   ligand.trans.inpcrd
#   ligand.prmtop
#   ligand.db
#   receptor.pdb
#   complex.prmtop
#   ligand.rb
#   receptor.prmtop
#   and frcmod files
# reading prmtopcrd/complex.tar.gz
#   extracted complex.pdb
#   extracted complex.prmtop
#   extracted complex.trans.inpcrd
# reading prmtopcrd/receptor.tar.gz
#   extracted receptor.pdb
#   extracted receptor.prmtop
#   extracted receptor.trans.inpcrd
# reading prmtopcrd/ligand.tar.gz
#   extracted ligand.db
#   extracted /Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod
#   extracted ligand.mol2
#   extracted ligand.prmtop
#   extracted ligand.rb
#   extracted ligand.trans.inpcrd
#
# *** Files ***
#   ligand_database: dock/ligand.db
#   forcefield: prmtopcrd/gaff2.dat
#   frcmodList: ['/Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod']
#   tarball:
#     L: prmtopcrd/ligand.tar.gz
#     R: prmtopcrd/receptor.tar.gz
#     RL: prmtopcrd/complex.tar.gz
#   prmtop:
#     L: dock/ligand.prmtop
#     R: dock/receptor.prmtop
#     RL: dock/complex.prmtop
#   inpcrd:
#     L: dock/ligand.trans.inpcrd
#     R: dock/receptor.trans.inpcrd
#     RL: dock/complex.trans.inpcrd
#   mol2:
#     L: dock/ligand.mol2
#   rb:
#     L: dock/ligand.rb
#   fixed_atoms:
#     R: dock/receptor.pdb
#     RL: dock/complex.pdb
#   grids:
#     LJr: grids/LJr.nc
#     LJa: grids/LJa.nc
#     ELE: grids/pbsa.nc
#   score: prmtopcrd/anchor_and_grow_scored.mol2
#   dir_cool: cool
#           DOES NOT EXIST
#
# >>> Setting up the simulation
#   considering a residue named "iga" as the ligand
#
# *** Simulation parameters and constants ***
#
# for cool:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 3
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 3.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Desolvated
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#
# for dock:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 4
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 20.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Desolvated
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   site: Sphere
#   site_center: array([ 1.74395,  1.74395,  1.74395])
#   site_max_R: 0.6
#   site_density: 10.0
#   pose: -1
#   k_pose: 200.0
#   MCMC_moves: 1
#   rmsd: True

# %%
from AlGDock.ForceFields.OBC.OBC import OBCForceField
FF = OBCForceField()
self.universe.setForceField(FF)
print self.universe.energyTerms()
(e,forces) = self.universe.energyAndGradients()
print forces.array

FF.set_strength(0.1)
self.universe.setForceField(FF)
print self.universe.energyTerms()
(e2,forces2) = self.universe.energyAndGradients()
print forces2.array

# %%
# self._run('all')
# Out:
# >>> Initial warming
#     starting at Mon, 16 Jan 2017 16:14:53 +0000
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/simtk/openmm/app/internal/amber_file_parser.py:1010: UserWarning: Non-optimal GB parameters detected for GB model OBC2
#   'model %s' % gbmodel)
#   minimized 223 configurations in 25.73 s
#   the first 10 energies are:
#   -305.30, -301.76, -303.33, -276.99, -296.15, -294.98, -292.05, -300.81, -302.06, -303.02
#   keeping 223 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 0 duplicated
#   ramped temperature from 20 to 300 K
#   changing energy from -308 to -223 kcal/mol
#
#   drew 10 configurations at 300 K in 0.18 s
#   Sampler 59/100=0.59 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.474e+00
#
#   drew 10 configurations at 300 K in 0.17 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.397e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   drew 10 configurations at 300 K in 0.17 s
#   Sampler 58/100=0.58 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.855e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 300 K in 0.17 s
#   Sampler 59/100=0.59 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.446e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 301 K in 0.17 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.237e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 301 K in 0.16 s
#   Sampler 54/100=0.54 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.871e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 301 K in 0.17 s
#   Sampler 59/100=0.59 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.587e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 303 K in 0.17 s
#   Sampler 60/100=0.60 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.900e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 303 K in 0.17 s
#   Sampler 69/100=0.69 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.828e+00
#   the estimated repX acceptance rate is 0.99
#
#   drew 10 configurations at 304 K in 0.17 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.463e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 304 K in 0.17 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.413e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 304 K in 0.17 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=4.346e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 304 K in 0.17 s
#   Sampler 73/100=0.73 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.239e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 305 K in 0.17 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.723e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 305 K in 0.17 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.303e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 306 K in 0.17 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.028e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 307 K in 0.17 s
#   Sampler 75/100=0.75 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.967e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 308 K in 0.17 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.810e+00
#   the estimated repX acceptance rate is 0.98
#
#   drew 10 configurations at 308 K in 0.17 s
#   Sampler 66/100=0.66 (0.3 s);
#   dt=3.00 fs; tL_tensor=2.263e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at
+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 403 K in 0.17 s
#   Sampler 66/100=0.66 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.211e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 404 K in 0.18 s
#   Sampler 67/100=0.67 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.185e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 404 K in 0.17 s
#   Sampler 52/100=0.52 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.160e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 404 K in 0.18 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.884e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 406 K in 0.17 s
#   Sampler 58/100=0.58 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.757e+00
#   the estimated repX acceptance rate is 0.99
#
#   drew 10 configurations at 406 K in 0.18 s
#   Sampler 77/100=0.77 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.831e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 406 K in 0.17 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.460e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 406 K in 0.17 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.164e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 407 K in 0.18 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.443e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 407 K in 0.17 s
#   Sampler 53/100=0.53 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.729e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 407 K in 0.17 s
#   Sampler 69/100=0.69 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.142e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 408 K in 0.17 s
#   Sampler 74/100=0.74 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.526e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 409 K in 0.18 s
#   Sampler 57/100=0.57 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.982e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 411 K in 0.17 s
#   Sampler 74/100=0.74 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.468e+00
#   the estimated repX acceptance rate is 0.98
#
#   drew 10 configurations at 411 K in 0.17 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.532e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 411 K in 0.18 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.467e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 411 K in 0.17 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.262e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 412 K in 0.17 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=4.379e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 412 K in 0.18 s
#   Sampler 71/100=0.71 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.462e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 413 K in 0.17 s
#   Sampler 66/100=0.66 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.738e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 413 K in 0.18 s
#   Sampler 69/100=0.69 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.266e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 414 K in 0.17 s
#   Sampler 55/100=0.55 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.306e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 415 K in 0.18 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.465e+00
#   the estimated repX acceptance rate is 0.99
#
#   drew 10 configurations at 415 K in 0.17 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.188e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 415 K in 0.18 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.527e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 415 K in 0.18 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.051e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 416 K in 0.17 s
#   Sampler 77/100=0.77 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.622e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 416 K in 0.17 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.596e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 417 K in 0.18 s
#   Sampler 67/100=0.67 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.178e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 418 K in 0.18 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.175e+00
#   the estimated repX acceptance rate is 0.99
#
#   drew 10 configurations at 418 K in 0.18 s
#   Sampler 72/100=0.72 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.883e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 418 K in 0.18 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.445e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 419 K in 0.18 s
#   Sampler 64/100=0.64 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.635e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 419 K in 0.18 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.232e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 419 K in 0.21 s
#   Sampler 57/100=0.57 (0.5 s);
#   dt=3.00 fs; tL_tensor=2.340e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 420 K in 0.20 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.257e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 421 K in 0.20 s
#   Sampler 70/100=0.70 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.838e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 422 K in 0.19 s
#   Sampler 61/100=0.61 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.006e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 423 K in 0.29 s
#   Sampler 70/100=0.70 (0.7 s);
#   dt=3.00 fs; tL_tensor=3.489e+00
#   the estimated repX acceptance rate is 0.99
#
#   drew 10 configurations at 423 K in 0.21 s
#   Sampler 69/100=0.69 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.267e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 423 K in 0.18 s
#   Sampler 80/100=0.80 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.757e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 423 K in 0.19 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.846e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 424 K in 0.20 s
#   Sampler 65/100=0.65 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.433e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 424 K in 0.19 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.968e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 425 K in 0.18 s
#   Sampler 71/100=0.71 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.825e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 425 K in 0.29 s
#   Sampler 67/100=0.67 (0.6 s);
#   dt=3.00 fs; tL_tensor=3.400e+00
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations at 426 K in 0.28 s
#   Sampler 68/100=0.68 (0.5 s);
#   dt=3.00 fs; tL_tensor=3.649e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 427 K in 0.26 s
#   Sampler 71/100=0.71 (0.5 s);
#   dt=3.00 fs; tL_tensor=1.599e+00
#   the estimated repX acceptance rate is 0.98
#
#   drew 10 configurations at 427 K in 0.34 s
#   Sampler 69/100=0.69 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.950e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 427 K in 0.19 s
#   Sampler 74/100=0.74 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.974e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 428 K in 0.18 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.970e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 428 K in 0.18 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=3.699e+00
#   rejected previous state with high estimated acceptance rate of 1.00
#   drew 10 configurations at 428 K in 0.19 s
# ...
#   drew 10 configurations at 600 K in 0.10 s
#   Sampler 67/100=0.67 (0.1 s);
#   dt=3.00 fs; tL_tensor=3.341e+00
#   the estimated repX acceptance rate is 1.00
#
#   reversing replicas, samples, and protocol
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
# Elapsed time for initial warming of 65 states: 2:18.85
#
# >>> Replica exchange for cooling
#     starting at Mon, 16 Jan 2017 16:17:12 +0000 GMT
#
#   saving 6 configurations in cycle 1 in 10.73 s (tau_ac=4.5283)
#   Sampler 1059/1625=0.65 (28.8 s); repX t 1.9 s
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   calculated cooling free energy of -109.71 RT using cycles 0 to 0
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: xtol=0.000000 is too small, no further improvement in the approximate
#   solution is possible.
#   warnings.warn(msg, RuntimeWarning)
#   calculated cooling free energy of -110.29 RT using cycles 1 to 1
#   saving 6 configurations in cycle 2 in 10.33 s (tau_ac=4.9692)
#   Sampler 1056/1625=0.65 (28.1 s); repX t 1.8 s
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   calculated cooling free energy of -110.25 RT using cycles 1 to 2
#
# Elapsed time for 2 cycles of replica exchange was 23.24 s
#
# >>> Postprocessing
#     starting at Mon, 16 Jan 2017 16:17:36 +0000
#
#   postprocessed cool, state 64, cycle 1, LNAMD_Gas in 0.23 s
#   postprocessed cool, state 64, cycle 0, LNAMD_OBC in 0.23 s
#   postprocessed cool, state 64, cycle 0, LNAMD_Gas in 0.23 s
#   postprocessed cool, state 64, cycle 1, LNAMD_OBC in 0.22 s
#   postprocessed cool, state 64, cycle 2, LNAMD_OBC in 0.16 s
#   postprocessed cool, state 64, cycle 2, LNAMD_Gas in 0.16 s
#   an average of 0.029216 s per LNAMD_OBC snapshot
#   an average of 0.029464 s per LNAMD_Gas snapshot
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
# Elapsed time for postprocessing was 1.11 s
#
# >>> Ligand free energy calculations
#     starting at Mon, 16 Jan 2017 16:17:37 +0000
#
#   calculated NAMD_Gas solvation free energy of 146.31 RT using cycles 0 to 0
#   calculated NAMD_Gas solvation free energy of 151.3 RT using cycles 1 to 1
#   calculated NAMD_Gas solvation free energy of 151.67 RT using cycles 1 to 2
#   calculated NAMD_OBC solvation free energy of 65.996 RT using cycles 0 to 0
#   calculated NAMD_OBC solvation free energy of 66.338 RT using cycles 1 to 1
#   calculated NAMD_OBC solvation free energy of 66.246 RT using cycles 1 to 2
#   wrote to f_L.pkl.gz
#
# Elapsed time for free energy calculation: 0.05 s
#
# >>> Initial docking
#     starting at Mon, 16 Jan 2017 16:17:37 +0000
#
#   LJr grid loaded from LJr.nc in 0.38 s
#   LJa grid loaded from LJa.nc in 0.16 s
#   ELE grid loaded from pbsa.nc in 0.03 s
#   minimized 3 configurations in 0.10 s
#   the first 3 energies are:
#   -75.86, -35.15, -15.42
#   keeping 3 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 0 duplicated
#   ramped temperature from 20 to 300 K
#   changing energy from -75.9 to 29.1 kcal/mol
#
#   sLJr grid loaded from LJr.nc in 0.32 s
#   sELE grid loaded from pbsa.nc in 0.03 s
#   drew 10 configurations with progress 1.000000e+00 in 0.54 s
#   Sampler 68/100=0.68 (0.4 s);
#   dt=3.00 fs, tL_tensor=2.482e+01
#   drew 10 configurations with progress 9.798526e-01 in 0.24 s
#   Sampler 67/100=0.67 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.665e+01
#   the estimated repX acceptance rate is 0.93
#
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   drew 10 configurations with progress 9.610911e-01 in 0.22 s
#   Sampler 63/100=0.63 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.340e+01
#   the estimated repX acceptance rate is 0.94
#
#   drew 10 configurations with progress 9.397244e-01 in 0.22 s
#   Sampler 53/100=0.53 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.079e+01
#   the estimated repX acceptance rate is 0.97
#
#   drew 10 configurations with progress 9.156769e-01 in 0.22 s
#   Sampler 63/100=0.63 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.682e+01
#   rejected previous state with high estimated acceptance rate of 0.99
#   drew 10 configurations with progress 8.785150e-01 in 0.22 s
#   Sampler 62/100=0.62 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.364e+01
#   the estimated repX acceptance rate is 0.72
#
#   drew 10 configurations with progress 8.418713e-01 in 0.22 s
#   Sampler 58/100=0.58 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.522e+01
#   the estimated repX acceptance rate is 0.93
#
#   drew 10 configurations with progress 8.090290e-01 in 0.22 s
#   Sampler 60/100=0.60 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.570e+01
#   the estimated repX acceptance rate is 0.88
#
#   drew 10 configurations with progress 7.771837e-01 in 0.23 s
#   Sampler 46/100=0.46 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.787e+01
#   the estimated repX acceptance rate is 0.89
#
#   drew 10 configurations with progress 7.491975e-01 in 0.22 s
#   Sampler 56/100=0.56 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.916e+01
#   the estimated repX acceptance rate is 0.95
#
#   drew 10 configurations with progress 7.231021e-01 in 0.22 s
#   Sampler 59/100=0.59 (0.5 s);
#   dt=3.00 fs, tL_tensor=1.161e+01
#   the estimated repX acceptance rate is 0.95
#
#   drew 10 configurations with progress 6.800252e-01 in 0.22 s
#   Sampler 56/100=0.56 (0.6 s);
#   dt=3.00 fs, tL_tensor=1.019e+01
#   the estimated repX acceptance rate is 0.84
#
#   drew 10 configurations with progress 6.309618e-01 in 0.23 s
#   Sampler 62/100=0.62 (0.6 s);
#   dt=3.00 fs, tL_tensor=6.922e+00
#   the estimated repX acceptance rate is 0.91
#
#   drew 10 configurations with progress 5.587317e-01 in 0.22 s
#   Sampler 67/100=0.67 (0.5 s);
#   dt=3.00 fs, tL_tensor=6.095e+00
#   the estimated repX acceptance rate is 0.87
#
#   drew 10 configurations with progress 4.767015e-01 in 0.22 s
#   Sampler 45/100=0.45 (0.6 s);
#   dt=3.00 fs, tL_tensor=2.143e+00
#   the estimated repX acceptance rate is 0.88
#
#   drew 10 configurations with progress 2.433752e-01 in 0.15 s
#   Sampler 55/100=0.55 (0.3 s);
#   dt=3.00 fs, tL_tensor=7.018e+00
#   rejected new state with low estimated acceptance rate of 3.60e-01
#   drew 10 configurations with progress 2.900405e-01 in 0.22 s
#   Sampler 57/100=0.57 (0.5 s);
#   dt=3.00 fs, tL_tensor=6.235e+00
#   rejected new state with low estimated acceptance rate of 3.53e-01
#   drew 10 configurations with progress 3.273727e-01 in 0.23 s
#   Sampler 43/100=0.43 (0.6 s);
#   dt=3.00 fs, tL_tensor=6.523e+00
#   the estimated repX acceptance rate is 0.65
#
#   drew 10 configurations with progress 2.507182e-01 in 0.16 s
#   Sampler 55/100=0.55 (0.3 s);
#   dt=3.00 fs, tL_tensor=6.995e+00
#   the estimated repX acceptance rate is 0.72
#
#   drew 10 configurations with progress 1.792355e-01 in 0.16 s
#   Sampler 61/100=0.61 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.130e+01
#   the estimated repX acceptance rate is 0.55
#
#   drew 10 configurations with progress 1.349780e-01 in 0.15 s
#   Sampler 64/100=0.64 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.137e+01
#   the estimated repX acceptance rate is 0.78
#
#   drew 10 configurations with progress 9.099850e-02 in 0.16 s
#   ExternalMC 1/50=0.02 (0.0 s); Sampler 67/100=0.67 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.596e+01
#   the estimated repX acceptance rate is 0.66
#
#   drew 10 configurations with progress 7.174139e-02 in 0.16 s
#   ExternalMC 3/50=0.06 (0.0 s); Sampler 80/100=0.80 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.446e+01
#   the estimated repX acceptance rate is 0.71
#
#   drew 10 configurations with progress 5.130173e-02 in 0.16 s
#   ExternalMC 9/50=0.18 (0.0 s); Sampler 71/100=0.71 (0.3 s);
#   dt=3.00 fs, tL_tensor=3.619e+01
#   the estimated repX acceptance rate is 0.77
#
#   drew 10 configurations with progress 3.748457e-02 in 0.16 s
#   ExternalMC 4/50=0.08 (0.0 s); Sampler 59/100=0.59 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.954e+01
#   the estimated repX acceptance rate is 0.58
#
#   drew 10 configurations with progress 2.055602e-02 in 0.16 s
#   ExternalMC 9/50=0.18 (0.0 s); Sampler 71/100=0.71 (0.3 s);
#   dt=3.00 fs, tL_tensor=4.788e+01
#   the estimated repX acceptance rate is 0.67
#
#   drew 10 configurations with progress 1.011384e-02 in 0.16 s
#   ExternalMC 9/50=0.18 (0.0 s); Sampler 76/100=0.76 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.300e+02
#   the estimated repX acceptance rate is 0.50
#
#   drew 10 configurations with progress 6.268776e-03 in 0.16 s
#   ExternalMC 9/50=0.18 (0.0 s); Sampler 63/100=0.63 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.042e+02
#   the estimated repX acceptance rate is 0.93
#
#   drew 10 configurations with progress 1.470297e-03 in 0.16 s
#   ExternalMC 16/50=0.32 (0.0 s); Sampler 68/100=0.68 (0.3 s);
#   dt=3.00 fs, tL_tensor=8.894e+02
#   rejected new state with low estimated acceptance rate of 2.85e-01
#   drew 10 configurations with progress 2.429993e-03 in 0.16 s
#   ExternalMC 14/50=0.28 (0.0 s); Sampler 67/100=0.67 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.994e+02
#   the estimated repX acceptance rate is 0.53
#
#   drew 10 configurations with progress 0.000000e+00 in 0.11 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 69/100=0.69 (0.1 s);
#   dt=3.00 fs, tL_tensor=3.211e+04
#   rejected new state with low estimated acceptance rate of 4.62e-30
#   drew 10 configurations with progress 4.239598e-04 in 0.17 s
#   ExternalMC 16/50=0.32 (0.0 s); Sampler 64/100=0.64 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.314e+03
#   rejected new state with low estimated acceptance rate of 3.85e-01
#   drew 10 configurations with progress 8.251665e-04 in 0.16 s
#   ExternalMC 11/50=0.22 (0.0 s); Sampler 70/100=0.70 (0.3 s);
#   dt=3.00 fs, tL_tensor=4.025e+02
#   the estimated repX acceptance rate is 0.54
#
#   drew 10 configurations with progress 0.000000e+00 in 0.10 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 64/100=0.64 (0.1 s);
#   dt=3.00 fs, tL_tensor=4.573e+04
#   rejected new state with low estimated acceptance rate of 3.63e-15
#   drew 10 configurations with progress 1.650333e-04 in 0.16 s
#   ExternalMC 20/50=0.40 (0.0 s); Sampler 64/100=0.64 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.495e+03
#   the estimated repX acceptance rate is 0.48
#
#   drew 10 configurations with progress 0.000000e+00 in 0.11 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 47/100=0.47 (0.1 s);
#   dt=3.00 fs, tL_tensor=3.659e+04
#   rejected new state with low estimated acceptance rate of 1.37e-02
#   drew 10 configurations with progress 4.741639e-06 in 0.16 s
#   ExternalMC 44/50=0.88 (0.0 s); Sampler 71/100=0.71 (0.3 s);
#   dt=3.00 fs, tL_tensor=4.309e+04
#   rejected new state with low estimated acceptance rate of 8.38e-02
#   drew 10 configurations with progress 3.679997e-05 in 0.17 s
#   ExternalMC 29/50=0.58 (0.0 s); Sampler 69/100=0.69 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.254e+04
#   rejected new state with low estimated acceptance rate of 3.28e-01
#   drew 10 configurations with progress 6.244663e-05 in 0.16 s
#   ExternalMC 20/50=0.40 (0.0 s); Sampler 63/100=0.63 (0.3 s);
#   dt=3.00 fs, tL_tensor=1.403e+04
#   the estimated repX acceptance rate is 0.61
#
#   drew 10 configurations with progress 2.680913e-05 in 0.16 s
#   ExternalMC 27/50=0.54 (0.0 s); Sampler 61/100=0.61 (0.3 s);
#   dt=3.00 fs, tL_tensor=2.461e+04
#   the estimated repX acceptance rate is 0.64
#
#   drew 10 configurations with progress 6.490550e-06 in 0.16 s
#   ExternalMC 47/50=0.94 (0.0 s); Sampler 66/100=0.66 (0.3 s);
#   dt=3.00 fs, tL_tensor=4.085e+04
#   the estimated repX acceptance rate is 0.54
#
#   drew 10 configurations with progress 0.000000e+00 in 0.10 s
#   ExternalMC 50/50=1.00 (0.0 s); Sampler 65/100=0.65 (0.1 s);
#   dt=3.00 fs, tL_tensor=4.187e+04
#   the estimated repX acceptance rate is 0.81
#
#   reversing replicas, samples, and protocol
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
# Elapsed time for initial docking of 32 states: 10.61 s
#
# >>> Reinitializing replica exchange configurations
#   minimized 3 configurations in 0.10 s
#   the first 3 energies are:
#   -75.86, -35.15, -15.42
#   keeping 32 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 29 duplicated
#
# >>> Replica exchange for docking
#     starting at Mon, 16 Jan 2017 16:17:47 +0000 GMT
#
#   saving 12 configurations in cycle 1 in 6.51 s (tau_ac=10.344)
#   ExternalMC 571/1750=0.33 (1.0 s); Sampler 313/800=0.39 (15.8 s); repX t 1.0 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   wrote to f_RL.pkl.gz
#   calculated grid scaling free energy of -11.56 RT using cycles 1 to 1
#   wrote to f_RL.pkl.gz
#   inserted state between 6.2447e-05 and 0.00016503 at 0.00011374
#   to improve acceptance rate from 0.34994 to 0.49799
#   wrote to f_RL.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   saving 12 configurations in cycle 2 in 7.08 s (tau_ac=10.458)
#   ExternalMC 572/1875=0.31 (1.1 s); Sampler 422/825=0.51 (17.2 s); repX t 1.0 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   calculated grid scaling free energy of -8.54 RT using cycles 1 to 2
#   wrote to f_RL.pkl.gz
#   inserted state between 0.00016503 and 0.00082517 at 0.0004951
#   to improve acceptance rate from 0.22836 to 0.31339
#   inserted state between 0.00016503 and 0.0004951 at 0.00033007
#   to improve acceptance rate from 0.31339 to 0.44831
#   wrote to f_RL.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   saving 12 configurations in cycle 3 in 7.55 s (tau_ac=10.849)
#   ExternalMC 643/2125=0.30 (1.3 s); Sampler 479/875=0.55 (18.3 s); repX t 1.1 s
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#   calculated grid scaling free energy of -5.41 RT using cycles 1 to 3
#   wrote to f_RL.pkl.gz
#   inserted state between 6.4906e-06 and 2.6809e-05 at 1.665e-05
#   to improve acceptance rate from 0.38921 to 0.51878
#   wrote to f_RL.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
#
# Elapsed time for 3 cycles of replica exchange was 25.39 s
#
# >>> Postprocessing
#     starting at Mon, 16 Jan 2017 16:18:13 +0000
#
#   postprocessed dock, state 35, cycle 0, LNAMD_Gas in 0.26 s
#   postprocessed dock, state 35, cycle 0, LNAMD_OBC in 0.25 s
#   postprocessed dock, state 35, cycle 1, LNAMD_Gas in 0.25 s
#   postprocessed dock, state 35, cycle 1, LNAMD_OBC in 0.25 s
#   postprocessed original, state 0, cycle 0, RNAMD_Gas in 0.63 s
#   postprocessed dock, state 35, cycle 2, LNAMD_Gas in 0.24 s
#   postprocessed dock, state 35, cycle 2, LNAMD_OBC in 0.24 s
#   postprocessed dock, state 35, cycle 3, LNAMD_Gas in 0.24 s
#   postprocessed dock, state 35, cycle 3, LNAMD_OBC in 0.24 s
#   postprocessed dock, state 35, cycle 0, RLNAMD_Gas in 0.71 s
#   postprocessed dock, state 35, cycle 1, RLNAMD_Gas in 0.71 s
#   postprocessed dock, state 35, cycle 2, RLNAMD_Gas in 0.68 s
#   postprocessed original, state 0, cycle 0, RNAMD_OBC in 2.73 s
#   postprocessed dock, state 35, cycle 3, RLNAMD_Gas in 0.68 s
#   postprocessed dock, state 35, cycle 0, RLNAMD_OBC in 19.03 s
#   postprocessed dock, state 35, cycle 1, RLNAMD_OBC in 22.12 s
#   postprocessed dock, state 35, cycle 2, RLNAMD_OBC in 21.79 s
#   postprocessed dock, state 35, cycle 3, RLNAMD_OBC in 21.41 s
#   an average of 0.060565 s per RLNAMD_Gas snapshot
#   an average of 2.7314 s per RNAMD_OBC snapshot
#   an average of 0.63289 s per RNAMD_Gas snapshot
#   an average of 0.021676 s per LNAMD_OBC snapshot
#   an average of 0.022027 s per LNAMD_Gas snapshot
#   an average of 1.8367 s per RLNAMD_OBC snapshot
#   wrote to dock_progress.pkl.gz
#   wrote to dock_progress.pkl.gz
#   wrote to dock_data.pkl.gz
#
# Elapsed time for postprocessing was 25.29 s
#   calculated grid scaling free energy of -4.97 RT using cycles 0 to 0
#   calculated grid scaling free energy of -12.63 RT using cycles 1 to 1
#   calculated grid scaling free energy of -9.40 RT using cycles 1 to 2
#   calculated grid scaling free energy of -5.88 RT using cycles 1 to 3
#   calculated NAMD_Gas binding PMF of -168.84 RT with cycles 0 to 0
#   calculated NAMD_Gas binding PMF of -211.08 RT with cycles 1 to 1
#   calculated NAMD_Gas binding PMF of -210.8 RT with cycles 1 to 2
#   calculated NAMD_Gas binding PMF of -210.52 RT with cycles 1 to 3
#   calculated NAMD_OBC binding PMF of -28.933 RT with cycles 0 to 0
#   calculated NAMD_OBC binding PMF of -56.501 RT with cycles 1 to 1
#   calculated NAMD_OBC binding PMF of -56.217 RT with cycles 1 to 2
#   calculated NAMD_OBC binding PMF of -55.937 RT with cycles 1 to 3
#   wrote to f_RL.pkl.gz
#
# Elapsed time for binding PMF estimation: 0.72 s
