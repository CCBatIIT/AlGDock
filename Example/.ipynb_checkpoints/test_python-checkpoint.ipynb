# %%
import AlGDock.BindingPMF_plots
from AlGDock.BindingPMF_plots import *
import os, shutil, glob

phases = ['NAMD_Gas', 'NAMD_OBC', 'OpenMM_OBC2']
# phases = ['sander_Gas', \
#   'sander_HCT', 'sander_OBC1', 'sander_OBC2', 'sander_GBn', 'sander_GBn2', \
#   'sander_PBSA', 'sander_ALPB_HCT', 'sander_ALPB_OBC1', 'sander_ALPB_OBC2', \
#   'sander_ALPB_GBn', 'gbnsr6_Still', 'gbnsr6_CHA']

self = AlGDock.BindingPMF_plots.BPMF_plots(\
  dir_dock='dock', dir_cool='cool',\
  ligand_database='prmtopcrd/ligand.db', \
  forcefield='prmtopcrd/gaff2.dat', \
  ligand_prmtop='prmtopcrd/ligand.prmtop', \
  ligand_inpcrd='prmtopcrd/ligand.trans.inpcrd', \
  ligand_mol2='prmtopcrd/ligand.mol2', \
  ligand_rb='prmtopcrd/ligand.rb', \
  receptor_prmtop='prmtopcrd/receptor.prmtop', \
  receptor_inpcrd='prmtopcrd/receptor.trans.inpcrd', \
  receptor_fixed_atoms='prmtopcrd/receptor.pdb', \
  complex_prmtop='prmtopcrd/complex.prmtop', \
  complex_inpcrd='prmtopcrd/complex.trans.inpcrd', \
  complex_fixed_atoms='prmtopcrd/complex.pdb', \
  score = 'prmtopcrd/xtal_plus_dock6_scored.mol2', \
  temperature_scaling = 'Quadratic', \
  pose = 0, \
  rmsd=True, \
  dir_grid='grids', \
  protocol='Adaptive', cool_therm_speed=25.0, dock_therm_speed=0.25, \
  T_HIGH=450.0, T_SIMMIN=300.0, T_TARGET=300.0, \
  sampler='HMC', \
  MCMC_moves=1, \
  sampling_importance_resampling = True, \
  solvation = 'Full', \
  seeds_per_state=10, steps_per_seed=200, darts_per_seed=0, \
  sweeps_per_cycle=50, snaps_per_cycle=25, attempts_per_sweep=100, \
  steps_per_sweep=50, darts_per_sweep=0, \
  cool_repX_cycles=3, dock_repX_cycles=4, \
  site='Sphere', site_center=[1.7416, 1.7416, 1.7416], \
  site_max_R=1.0, \
  site_density=10., \
  phases=phases, \
  cores=-1, \
  random_seed=-1, \
  max_time=240, \
  keep_intermediate=True)
# Out:
# ###########
# # AlGDock #
# ###########
# Molecular docking with adaptively scaled alchemical interaction grids
#
# in /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.py
# last modified Fri Sep  1 23:11:28 2017
#
# using 4/4 available cores
# using random number seed of -1
#   no progress information for dock
#   no progress information for cool
#
# *** Directories ***
#   start: /Users/dminh/Installers/AlGDock-0.0.1/Example
#   cool: /Users/dminh/Installers/AlGDock-0.0.1/Example/cool
#   dock: /Users/dminh/Installers/AlGDock-0.0.1/Example/dock
#
# *** Files ***
#   ligand_database: prmtopcrd/ligand.db
#   forcefield: ../Data/gaff2.dat
#   frcmodList: ['/Users/dminh/Installers/AlGDock-0.0.1/Example/prmtopcrd/ligand.frcmod']
#   prmtop:
#     L: prmtopcrd/ligand.prmtop
#     R: prmtopcrd/receptor.prmtop
#     RL: prmtopcrd/complex.prmtop
#   inpcrd:
#     L: prmtopcrd/ligand.trans.inpcrd
#     R: prmtopcrd/receptor.trans.inpcrd
#     RL: prmtopcrd/complex.trans.inpcrd
#   mol2:
#     L: prmtopcrd/ligand.mol2
#   fixed_atoms:
#     R: prmtopcrd/receptor.pdb
#     RL: prmtopcrd/complex.pdb
#   grids:
#     LJr: grids/LJr.nc
#     LJa: grids/LJa.nc
#     ELE: grids/pbsa.nc
#     desolv: grids/desolv.nc
#   score: prmtopcrd/xtal_plus_dock6_scored.mol2
#   dir_cool: cool
#           DOES NOT EXIST
#
# ligand residue name: iga
#
# *** Simulation parameters and constants ***
#
# for cool:
#   protocol: Adaptive
#   therm_speed: 25.0
#   T_HIGH: 450.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 5
#   delta_t: 4.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 3
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 50
#   snaps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 50
#   darts_per_sweep: 0
#   phases: ['NAMD_Gas', 'NAMD_OBC', 'OpenMM_OBC2']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: True
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   delta_t_CD: 4.0
#
# for dock:
#   protocol: Adaptive
#   therm_speed: 0.25
#   T_HIGH: 450.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 5
#   delta_t: 4.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 4
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 50
#   snaps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 50
#   darts_per_sweep: 0
#   phases: ['NAMD_Gas', 'NAMD_OBC', 'OpenMM_OBC2']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: True
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   temperature_scaling: Quadratic
#   site: Sphere
#   site_center: array([ 1.7416,  1.7416,  1.7416])
#   site_max_R: 1.0
#   site_density: 10.0
#   pose: 0
#   k_pose: 1000.0
#   MCMC_moves: 1
#   rmsd: True
#   delta_t_CD: 4.0

# %%
self._clear_lock('cool')
self._clear_lock('dock')

# %%
self._run('all')
# Out:
# >>> Initial warming, starting at Sat, 02 Sep 2017 18:09:52
#
#   minimized 693 configurations in 1:7.39
#   the first 10 energies are:
#   -300.19, -295.78, -299.43, -297.72, -294.37, -289.34, -293.65, -284.60, -283.88, -291.62
#   keeping 693 minimized configurations out of
#   0 from xtal, 693 from dock6, 0 from initial docking, and 0 duplicated
#   minimized to -301 kcal/mol over 10 steps
#   T = 20, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.812
#   T = 21, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.832
#   T = 24, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.844
#   T = 26, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.828
#   T = 29, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.836
#   T = 31, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.872
#   T = 35, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.836
#   T = 38, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.856
#   T = 42, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.852
#   T = 46, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.868
#   T = 50, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.852
#   T = 55, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.832
#   T = 61, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.792
#   T = 67, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.820
#   T = 73, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.828
#   T = 81, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.848
#   T = 89, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.824
#   T = 97, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.848
#   T = 107, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.856
#   T = 117, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.812
#   T = 129, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.848
#   T = 142, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.804
#   T = 156, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.816
#   T = 171, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.868
#   T = 188, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.828
#   T = 206, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.844
#   T = 226, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.836
#   T = 248, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.852
#   T = 273, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.856
#   T = 300, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.844
#   ramped temperature from 20 to 300 K in 10.00 s, changing energy to -224 kcal/mol
#   at 300 K in 0.59 s: Sampler 23/40=0.57 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.818e+00
#   at 313 K in 0.15 s: Sampler 23/40=0.57 (0.3 s);
#     dt=3.50 fs; tL_tensor=3.32e+00; <acc>=0.83
#   at 321 K in 0.16 s: Sampler 21/40=0.53 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.87e+00; <acc>=0.90
#   at 336 K in 0.16 s: Sampler 19/40=0.47 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.74e+00; <acc>=0.94
#   at 351 K in 0.16 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.50 fs; tL_tensor=2.27e+00; <acc>=0.90
#   at 363 K in 0.16 s: Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=2.02e+00; <acc>=0.86
#   at 376 K in 0.33 s: Sampler 23/40=0.57 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.49e+00; <acc>=0.83
#   at 387 K in 0.15 s: Sampler 27/40=0.68 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.68e+00; <acc>=0.91
#   at 397 K in 0.16 s: Sampler 20/40=0.50 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.71e+00; <acc>=0.92
#   at 412 K in 0.16 s: Sampler 19/40=0.47 (0.3 s);
#     dt=3.25 fs; tL_tensor=1.96e+00; <acc>=0.90
#   at 426 K in 0.16 s: Sampler 22/40=0.55 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.37e+00; <acc>=0.83
#   at 438 K in 0.16 s: Sampler 19/40=0.47 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.10e+00; <acc>=0.93
#   at 450 K in 0.15 s: Sampler 28/40=0.70 (0.3 s);
#     dt=3.25 fs; tL_tensor=1.81e+00; <acc>=0.96
#   reversing replicas, samples, and protocol
#   saved cool progress and data
#
# Elapsed time for initial warming of 13 states: 1:21.75
#
# >>> Replica exchange for cooling, starting at Sat, 02 Sep 2017 18:11:14
#
#   completed cycle 1 in 4.95 s
#   Sampler 317/650=0.49 (7.8 s); repX t 0.7 s
#   saved cool progress and data
#
#   calculated cooling free energy of -26.98 RT using cycles 0 to 0
#   calculated cooling free energy of -27.14 RT using cycles 1 to 1
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: xtol=0.000000 is too small, no further improvement in the approximate
#   solution is possible.
#   warnings.warn(msg, RuntimeWarning)
#   completed cycle 2 in 4.30 s
#   Sampler 334/650=0.51 (7.3 s); repX t 0.6 s
#   saved cool progress and data
#
#   calculated cooling free energy of -26.87 RT using cycles 1 to 2
#
# Elapsed time for 2 cycles of replica exchange was 12.71 s
#
# >>> Postprocessing, starting at Sat, 02 Sep 2017 18:11:26
#
#   postprocessed cool, state 12, cycle 0, LNAMD_OBC in 0.35 s
#   postprocessed cool, state 12, cycle 0, LNAMD_Gas in 0.36 s
#   postprocessed cool, state 12, cycle 1, LNAMD_OBC in 0.24 s
#   postprocessed cool, state 12, cycle 1, LNAMD_Gas in 0.25 s
#   postprocessed cool, state 12, cycle 2, LNAMD_Gas in 0.25 s
#   postprocessed cool, state 12, cycle 2, LNAMD_OBC in 0.20 s
#   postprocessed cool, state 12, cycle 1, LOpenMM_OBC2 in 2.97 s
#   postprocessed cool, state 12, cycle 0, LOpenMM_OBC2 in 3.90 s
#   postprocessed cool, state 12, cycle 2, LOpenMM_OBC2 in 3.75 s
#   an average of 1.2506 s per LOpenMM_OBC2 snapshot
#   an average of 0.086054 s per LNAMD_OBC snapshot
#   an average of 0.095529 s per LNAMD_Gas snapshot
#   saved cool progress and data
#
# Elapsed time for postprocessing was 6.16 s
# Calculating matrix ...
#  Done
#
# >>> Ligand free energy calculations, starting at Sat, 02 Sep 2017 18:11:33
#
#   calculated NAMD_Gas solvation free energy of 147.09 RT using cycles 0 to 0
#   calculated NAMD_Gas solvation free energy of 149.81 RT using cycles 1 to 1
#   calculated NAMD_Gas solvation free energy of 147.67 RT using cycles 1 to 2
#   calculated NAMD_OBC solvation free energy of 63.551 RT using cycles 0 to 0
#   calculated NAMD_OBC solvation free energy of 63.302 RT using cycles 1 to 1
#   calculated NAMD_OBC solvation free energy of 63.357 RT using cycles 1 to 2
#   calculated OpenMM_OBC2 solvation free energy of 72.625 RT using cycles 0 to 0
#   calculated OpenMM_OBC2 solvation free energy of 72.654 RT using cycles 1 to 1
#   calculated OpenMM_OBC2 solvation free energy of 72.68 RT using cycles 1 to 2
#   wrote to f_L.pkl.gz
#
# Elapsed time for free energy calculation: 0.16 s
#
# >>> Initial docking, starting at Sat, 02 Sep 2017 18:11:33
#
#   LJr grid loaded from LJr.nc in 0.47 s
#   LJa grid loaded from LJa.nc in 0.24 s
#   ELE grid loaded from pbsa.nc in 0.04 s
#   keeping 693 configurations out of
#   0 from xtal, 693 from dock6, 0 from initial docking, and 0 duplicated
#   minimized to -440 kcal/mol over 950 steps
#   T = 20, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.668
#   T = 21, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.768
#   T = 24, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.760
#   T = 26, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.812
#   T = 29, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.776
#   T = 31, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.744
#   T = 35, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.772
#   T = 38, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.736
#   T = 42, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.744
#   T = 46, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.696
#   T = 50, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.748
#   T = 55, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.828
#   T = 61, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.752
#   T = 67, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.744
#   T = 73, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.748
#   T = 81, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.820
#   T = 89, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.704
#   T = 97, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.696
#   T = 107, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.764
#   T = 117, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.780
#   T = 129, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.744
#   T = 142, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.736
#   T = 156, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.760
#   T = 171, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.728
#   T = 188, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.736
#   T = 206, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.764
#   T = 226, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.780
#   T = 248, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.780
#   T = 273, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.736
#   T = 300, delta_t = 2.000 fs, steps_per_trial = 10, acc_rate = 0.728
#   ramped temperature from 20 to 300 K in 11.08 s, changing energy to -308 kcal/mol
#   sLJr grid loaded from LJr.nc in 0.33 s
#   sELE grid loaded from pbsa.nc in 0.03 s
#
#   at a=1.000e+00 in 13.04 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.75 fs, tL_tensor=1.219e+01
#   at a=9.795e-01 in 0.18 s: Sampler 17/40=0.42 (0.4 s);
#     dt=2.75 fs; tL_tensor=1.618e+01; <acc>=0.96
#   at a=9.635e-01 in 0.17 s: Sampler 16/40=0.40 (0.4 s);
#     dt=2.75 fs; tL_tensor=1.308e+01; <acc>=0.93
#   at a=9.438e-01 in 0.35 s: Sampler 25/40=0.62 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.197e+01; <acc>=0.81
#   at a=9.221e-01 in 0.17 s: Sampler 28/40=0.70 (0.4 s);
#     dt=2.50 fs; tL_tensor=7.709e+00; <acc>=0.97
#   at a=8.886e-01 in 0.17 s: Sampler 22/40=0.55 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.217e+01; <acc>=0.69
#   at a=8.668e-01 in 0.17 s: Sampler 19/40=0.47 (0.4 s);
#     dt=2.50 fs; tL_tensor=9.873e+00; <acc>=0.95
#   at a=8.403e-01 in 0.17 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.075e+01; <acc>=0.87
#   at a=8.158e-01 in 0.17 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.191e+01; <acc>=0.81
#   at a=7.935e-01 in 0.17 s: Sampler 20/40=0.50 (0.4 s);
#     dt=2.50 fs; tL_tensor=8.801e+00; <acc>=0.93
#   at a=7.636e-01 in 0.17 s: Sampler 28/40=0.70 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.155e+01; <acc>=0.90
#   at a=7.403e-01 in 0.17 s: Sampler 20/40=0.50 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.429e+01; <acc>=0.88
#   at a=7.215e-01 in 0.17 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.362e+01; <acc>=0.86
#   at a=7.019e-01 in 0.17 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=2.296e+01; <acc>=0.72
#   at a=6.900e-01 in 0.17 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.227e+01; <acc>=0.97
#   at a=6.687e-01 in 0.17 s: Sampler 26/40=0.65 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.521e+01; <acc>=0.86
#   at a=6.506e-01 in 0.18 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.415e+01; <acc>=0.85
#   at a=6.310e-01 in 0.32 s: Sampler 20/40=0.50 (0.5 s);
#     dt=2.50 fs; tL_tensor=1.694e+01; <acc>=0.81
#   at a=6.142e-01 in 0.18 s: Sampler 25/40=0.62 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.521e+01; <acc>=0.92
#   at a=5.959e-01 in 0.19 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.935e+01; <acc>=0.78
#   at a=5.808e-01 in 0.23 s: Sampler 18/40=0.45 (0.5 s);
#     dt=2.50 fs; tL_tensor=1.960e+01; <acc>=0.86
#   at a=5.661e-01 in 0.21 s: Sampler 18/40=0.45 (0.4 s);
#     dt=2.50 fs; tL_tensor=3.523e+01; <acc>=0.84
#   at a=5.575e-01 in 0.20 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=2.065e+01; <acc>=0.95
#   at a=5.438e-01 in 0.18 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=3.395e+01; <acc>=0.79
#   at a=5.346e-01 in 0.22 s: Sampler 19/40=0.47 (0.5 s);
#     dt=2.50 fs; tL_tensor=3.327e+01; <acc>=0.86
#   at a=5.253e-01 in 0.21 s: Sampler 27/40=0.68 (0.5 s);
#     dt=2.50 fs; tL_tensor=1.834e+01; <acc>=0.92
#   at a=5.074e-01 in 0.21 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=3.817e+01; <acc>=0.77
#   at a=5.000e-01 in 0.16 s: Sampler 19/40=0.47 (0.3 s);
#     dt=2.50 fs; tL_tensor=1.038e+01; <acc>=0.99
#   at a=4.500e-01 in 0.17 s: Sampler 19/40=0.47 (0.4 s);
#     dt=2.50 fs; tL_tensor=3.823e+00; <acc>=0.99
#   rejected past state with high estimated acceptance rate
#   at a=4.000e-01 in 0.18 s: Sampler 27/40=0.68 (0.4 s);
#     dt=2.50 fs; tL_tensor=5.952e+00; <acc>=0.98
#   at a=3.500e-01 in 0.18 s: Sampler 26/40=0.65 (0.4 s);
#     dt=2.50 fs; tL_tensor=2.656e+00; <acc>=0.94
#   at a=3.000e-01 in 0.22 s: Sampler 26/40=0.65 (0.5 s);
#     dt=2.50 fs; tL_tensor=3.511e+00; <acc>=0.90
#   at a=2.500e-01 in 0.21 s: Sampler 17/40=0.42 (0.4 s);
#     dt=2.50 fs; tL_tensor=8.517e+00; <acc>=0.64
#   at a=2.283e-01 in 0.19 s: Sampler 25/40=0.62 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.467e+01; <acc>=0.68
#   at a=2.125e-01 in 0.16 s: Sampler 19/40=0.47 (0.3 s);
#     dt=2.50 fs; tL_tensor=1.378e+01; <acc>=0.88
#   at a=1.949e-01 in 0.18 s: Sampler 19/40=0.47 (0.4 s);
#     dt=2.50 fs; tL_tensor=1.455e+01; <acc>=0.86
#   at a=1.778e-01 in 0.16 s: Sampler 22/40=0.55 (0.3 s);
#     dt=2.50 fs; tL_tensor=1.860e+01; <acc>=0.86
#   at a=1.640e-01 in 0.17 s: Sampler 21/40=0.53 (0.4 s);
#     dt=2.50 fs; tL_tensor=4.048e+01; <acc>=0.75
#   at a=1.576e-01 in 0.16 s: Sampler 27/40=0.68 (0.3 s);
#     dt=2.50 fs; tL_tensor=2.628e+01; <acc>=0.94
#   at a=1.478e-01 in 0.34 s: Sampler 31/40=0.78 (0.3 s);
#     dt=2.25 fs; tL_tensor=2.879e+01; <acc>=0.78
#   at a=1.387e-01 in 0.34 s: Sampler 28/40=0.70 (0.3 s);
#     dt=2.37 fs; tL_tensor=3.095e+01; <acc>=0.87
#   at a=1.302e-01 in 0.16 s: Sampler 30/40=0.75 (0.4 s);
#     dt=2.37 fs; tL_tensor=2.635e+01; <acc>=0.91
#   at a=1.202e-01 in 0.16 s: Sampler 29/40=0.72 (0.3 s);
#     dt=2.37 fs; tL_tensor=2.972e+01; <acc>=0.84
#   at a=1.112e-01 in 0.17 s: Sampler 30/40=0.75 (0.3 s);
#     dt=2.37 fs; tL_tensor=3.745e+01; <acc>=0.77
#   at a=1.040e-01 in 0.17 s: Sampler 29/40=0.72 (0.3 s);
#     dt=2.37 fs; tL_tensor=3.339e+01; <acc>=0.94
#   at a=9.600e-02 in 0.16 s: Sampler 27/40=0.68 (0.3 s);
#     dt=2.37 fs; tL_tensor=3.277e+01; <acc>=0.80
#   at a=8.775e-02 in 0.16 s: Sampler 29/40=0.72 (0.3 s);
#     dt=2.37 fs; tL_tensor=4.389e+01; <acc>=0.83
#   at a=8.152e-02 in 0.16 s: Sampler 31/40=0.78 (0.3 s);
#     dt=2.37 fs; tL_tensor=3.815e+01; <acc>=0.91
#   at a=7.449e-02 in 0.16 s: Sampler 31/40=0.78 (0.3 s);
#     dt=2.37 fs; tL_tensor=4.991e+01; <acc>=0.87
#   at a=6.901e-02 in 0.16 s: Sampler 22/40=0.55 (0.3 s);
#     dt=2.37 fs; tL_tensor=6.563e+01; <acc>=0.77
#   at a=6.489e-02 in 0.16 s: Sampler 25/40=0.62 (0.3 s);
#     dt=2.37 fs; tL_tensor=6.252e+01; <acc>=0.90
#   at a=6.064e-02 in 0.16 s: Sampler 29/40=0.72 (0.3 s);
#     dt=2.37 fs; tL_tensor=2.379e+01; <acc>=0.95
#   at a=4.943e-02 in 0.16 s: Sampler 24/40=0.60 (0.3 s);
#     dt=2.37 fs; tL_tensor=6.010e+01; <acc>=0.51
#   at a=4.432e-02 in 0.16 s: Sampler 28/40=0.70 (0.3 s);
#     dt=2.37 fs; tL_tensor=4.696e+01; <acc>=0.95
#   at a=3.839e-02 in 0.16 s: Sampler 28/40=0.70 (0.3 s);
#     dt=2.37 fs; tL_tensor=7.340e+01; <acc>=0.79
#   at a=3.447e-02 in 0.21 s: Sampler 25/40=0.62 (0.3 s);
#     dt=2.37 fs; tL_tensor=7.729e+01; <acc>=0.94
#   at a=3.087e-02 in 0.43 s: Sampler 27/40=0.68 (0.3 s);
#     dt=2.50 fs; tL_tensor=6.236e+01; <acc>=0.87
#   at a=2.640e-02 in 0.17 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.50 fs; tL_tensor=9.693e+01; <acc>=0.85
#   at a=2.339e-02 in 0.21 s: Sampler 32/40=0.80 (0.3 s);
#     dt=2.50 fs; tL_tensor=1.127e+02; <acc>=0.82
#   at a=2.089e-02 in 0.17 s: Sampler 30/40=0.75 (0.4 s);
#     dt=2.50 fs; tL_tensor=6.176e+01; <acc>=0.93
#   at a=1.638e-02 in 0.20 s: Sampler 30/40=0.75 (0.4 s);
#     dt=2.50 fs; tL_tensor=9.186e+01; <acc>=0.81
#   at a=1.293e-02 in 0.21 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.50 fs; tL_tensor=7.015e+01; <acc>=0.91
#   at a=8.442e-03 in 0.38 s: Sampler 23/40=0.57 (0.3 s);
#     dt=2.25 fs; tL_tensor=2.270e+02; <acc>=0.81
#   at a=6.759e-03 in 0.16 s: Sampler 27/40=0.68 (0.3 s);
#     dt=2.25 fs; tL_tensor=1.512e+02; <acc>=0.93
#   at a=4.700e-03 in 0.22 s: Sampler 29/40=0.72 (0.4 s);
#     dt=2.25 fs; tL_tensor=2.029e+02; <acc>=0.85
#   at a=2.934e-03 in 0.22 s: Sampler 32/40=0.80 (0.4 s);
#     dt=2.25 fs; tL_tensor=1.405e+02; <acc>=0.93
#   at a=1.107e-04 in 0.20 s: Sampler 24/40=0.60 (0.4 s);
#     dt=2.25 fs; tL_tensor=1.526e+02; <acc>=0.93
#   at a=0.000e+00 in 0.22 s: Sampler 23/40=0.57 (0.4 s);
#     dt=2.25 fs; tL_tensor=3.536e+00; <acc>=1.00
#   reversing replicas, samples, and protocol
#   saved dock progress and data
#
# Elapsed time for initial docking of 67 states: 28.01 s
#
# >>> Replica exchange for docking, starting at Sat, 02 Sep 2017 18:12:01
#
#   completed cycle 1 in 17.93 s
#   Sampler 2158/3350=0.64 (38.1 s); repX t 4.0 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -55.36 RT using cycles 1 to 1
#   wrote to f_RL_pose000.pkl.gz
#   completed cycle 2 in 17.22 s
#   Sampler 2148/3350=0.64 (36.9 s); repX t 4.0 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -55.00 RT using cycles 1 to 2
#   wrote to f_RL_pose000.pkl.gz
#   completed cycle 3 in 16.81 s
#   Sampler 2129/3350=0.64 (36.1 s); repX t 3.9 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -54.63 RT using cycles 1 to 3
#   wrote to f_RL_pose000.pkl.gz
#
# Elapsed time for 3 cycles of replica exchange was 1:0.91
#
# >>> Postprocessing, starting at Sat, 02 Sep 2017 18:13:02
#
#   postprocessed original, state 0, cycle 0, RNAMD_Gas in 0.88 s
#   postprocessed dock, state 66, cycle 0, LNAMD_Gas in 0.24 s
#   postprocessed dock, state 66, cycle 0, LNAMD_OBC in 0.26 s
#   postprocessed dock, state 66, cycle 0, LOpenMM_OBC2 in 3.49 s
#   postprocessed dock, state 66, cycle 1, LNAMD_Gas in 0.23 s
#   postprocessed dock, state 66, cycle 1, LNAMD_OBC in 0.22 s
#   postprocessed dock, state 66, cycle 2, LOpenMM_OBC2 in 0.01 s
#   postprocessed dock, state 66, cycle 2, LNAMD_Gas in 0.23 s
#   postprocessed original, state 0, cycle 0, RNAMD_OBC in 4.40 s
#   postprocessed dock, state 66, cycle 2, LNAMD_OBC in 0.27 s
#   postprocessed dock, state 66, cycle 3, LNAMD_Gas in 0.29 s
#   postprocessed dock, state 66, cycle 3, LNAMD_OBC in 0.25 s
#   postprocessed dock, state 66, cycle 1, LOpenMM_OBC2 in 3.71 s
#   postprocessed dock, state 66, cycle 0, RLNAMD_Gas in 1.26 s
#   postprocessed dock, state 66, cycle 3, LOpenMM_OBC2 in 3.75 s
#   postprocessed original, state 0, cycle 0, ROpenMM_OBC2 in 10.48 s
#   postprocessed dock, state 66, cycle 1, RLNAMD_Gas in 0.85 s
#   postprocessed dock, state 66, cycle 1, RLNAMD_OBC in 7.92 s
#   postprocessed dock, state 66, cycle 0, RLOpenMM_OBC2 in 15.03 s
#   postprocessed dock, state 66, cycle 2, RLNAMD_Gas in 0.94 s
#   postprocessed dock, state 66, cycle 1, RLOpenMM_OBC2 in 13.01 s
#   postprocessed dock, state 66, cycle 3, RLOpenMM_OBC2 in 0.95 s
#   postprocessed dock, state 66, cycle 3, RLNAMD_Gas in 0.98 s
#   postprocessed dock, state 66, cycle 2, RLNAMD_OBC in 10.00 s
#   postprocessed dock, state 66, cycle 2, RLOpenMM_OBC2 in 12.10 s
#   postprocessed dock, state 66, cycle 3, RLNAMD_OBC in 9.48 s
#   postprocessed dock, state 66, cycle 0, RLNAMD_OBC in 34.64 s
#   an average of 0.37682 s per RLNAMD_Gas snapshot
#   an average of 4.4008 s per RNAMD_OBC snapshot
#   an average of 1.0203 s per LOpenMM_OBC2 snapshot
#   an average of 10.484 s per ROpenMM_OBC2 snapshot
#   an average of 3.6327 s per RLOpenMM_OBC2 snapshot
#   an average of 0.88476 s per RNAMD_Gas snapshot
#   an average of 0.09853 s per LNAMD_OBC snapshot
#   an average of 0.099181 s per LNAMD_Gas snapshot
#   an average of 4.2913 s per RLNAMD_OBC snapshot
#   saved dock progress and data
#   saved dock progress and data
#
# Elapsed time for postprocessing was 43.39 s
#   calculated grid scaling free energy of -58.64 RT using cycles 0 to 0
# Calculating matrix ...
#  Done
#   calculated NAMD_Gas binding PMF of -215.82 RT with cycles 0 to 0
#   calculated NAMD_Gas binding PMF of -201.9 RT with cycles 1 to 1
#   calculated NAMD_Gas binding PMF of -201.21 RT with cycles 1 to 2
#   calculated NAMD_Gas binding PMF of -205.75 RT with cycles 1 to 3
#   calculated NAMD_OBC binding PMF of -61.964 RT with cycles 0 to 0
#   calculated NAMD_OBC binding PMF of -49.88 RT with cycles 1 to 1
#   calculated NAMD_OBC binding PMF of -49.19 RT with cycles 1 to 2
#   calculated NAMD_OBC binding PMF of -53.845 RT with cycles 1 to 3
#   calculated OpenMM_OBC2 binding PMF of -77.023 RT with cycles 0 to 0
#   calculated OpenMM_OBC2 binding PMF of -63.651 RT with cycles 1 to 1
#   calculated OpenMM_OBC2 binding PMF of -62.961 RT with cycles 1 to 2
#   calculated OpenMM_OBC2 binding PMF of -67.894 RT with cycles 1 to 3
#   wrote to f_RL_pose000.pkl.gz
#
# Elapsed time for binding PMF estimation: 0.40 s
#
# Elapsed time for execution of all: 3:54.06

# %%
readOnly=False
do_solvation=True
redo=True

# %%
    # Initialize variables as empty lists or by loading data
    if self.params['dock']['pose']==-1:
      f_RL_FN = os.path.join(self.dir['dock'],'f_RL.pkl.gz')
    else:
      f_RL_FN = os.path.join(self.dir['dock'], \
        'f_RL_pose%03d.pkl.gz'%self.params['dock']['pose'])
    
    dat = self._load_pkl_gz(f_RL_FN)
    if (dat is not None):
      (self.f_L, self.stats_RL, self.f_RL, self.B) = dat
    else:
      self._clear_f_RL()

    if redo:
      for key in self.f_RL.keys():
        if key!='grid_MBAR':
          self.f_RL[key] = []
      self.B = {'MMTK_MBAR':[]}
      for phase in self.params['dock']['phases']:
        for method in ['min_Psi','mean_Psi','EXP','MBAR']:
          self.B[phase+'_'+method] = []

# %%
    start_string = "\n>>> Complex free energy calculations, starting at " + \
      time.strftime("%a, %d %b %Y %H:%M:%S", time.localtime()) + "\n"
    self.start_times['BPMF'] = time.time()

    updated = False
    def set_updated_to_True(updated, quiet=False):
      if (updated is False) and (not quiet):
        self.tee(start_string)
      updated = True
      return updated

    K = len(self.dock_protocol)
    
    # Store stats_RL
    # Internal energies
    self.stats_RL['u_K_sampled'] = \
      [self._u_kln([self.dock_Es[-1][c]],[self.dock_protocol[-1]]) \
        for c in range(self._dock_cycle)]
    self.stats_RL['u_KK'] = \
      [np.sum([self._u_kln([self.dock_Es[k][c]],[self.dock_protocol[k]]) \
        for k in range(len(self.dock_protocol))],0) \
          for c in range(self._dock_cycle)]

    # Interaction energies
    for c in range(len(self.stats_RL['Psi_grid']), self._dock_cycle):
      self.stats_RL['Psi_grid'].append(
          (self.dock_Es[-1][c]['LJr'] + \
           self.dock_Es[-1][c]['LJa'] + \
           self.dock_Es[-1][c]['ELE'])/self.RT_SIMMIN)
      updated = set_updated_to_True(updated, quiet=~do_solvation)

    # Estimate cycle at which simulation has equilibrated
    eqc_o = self.stats_RL['equilibrated_cycle']
    self.stats_RL['equilibrated_cycle'] = self._get_equilibrated_cycle('dock')
    if self.stats_RL['equilibrated_cycle']!=eqc_o:
      updated = set_updated_to_True(updated, quiet=~do_solvation)

# %%
    # Calculate docking free energies that have not already been calculated
    while len(self.f_RL['grid_MBAR'])<self._dock_cycle:
      self.f_RL['grid_MBAR'].append([])
    while len(self.stats_RL['mean_acc'])<self._dock_cycle:
      self.stats_RL['mean_acc'].append([])
    
    for c in range(self._dock_cycle):
      # If solvation free energies are not being calculated,
      # only calculate the grid free energy for the current cycle
      if (not do_solvation) and c<(self._dock_cycle-1):
        continue
      if self.f_RL['grid_MBAR'][c]!=[]:
        continue

      fromCycle = self.stats_RL['equilibrated_cycle'][c]
      extractCycles = range(fromCycle, c+1)
      
      # Extract relevant energies
      dock_Es = [Es[fromCycle:c+1] \
        for Es in self.dock_Es]
      
      # Use MBAR for the grid scaling free energy estimate
      (u_kln,N_k) = self._u_kln(dock_Es,self.dock_protocol)
      MBAR = self._run_MBAR(u_kln,N_k)[0]
      self.f_RL['grid_MBAR'][c] = MBAR
      updated = set_updated_to_True(updated, quiet=~do_solvation)
      
      self.tee("  calculated grid scaling free energy of %.2f RT "%(\
                  self.f_RL['grid_MBAR'][c][-1])+\
               "using cycles %d to %d"%(fromCycle, c))

      # Average acceptance probabilities
      mean_acc = np.zeros(K-1)
      for k in range(0, K-1):
        (u_kln,N_k) = self._u_kln(dock_Es[k:k+2],self.dock_protocol[k:k+2])
        N = min(N_k)
        acc = np.exp(-u_kln[0,1,:N]-u_kln[1,0,:N]+u_kln[0,0,:N]+u_kln[1,1,:N])
        mean_acc[k] = np.mean(np.minimum(acc,np.ones(acc.shape)))
      self.stats_RL['mean_acc'][c] = mean_acc

# %%
    # Make sure postprocessing is complete
    pp_complete = self._postprocess()
    self.calc_f_L()
# Out:
# Calculating matrix ...
#  Done
# True

# %%
    # Store stats_RL internal energies for phases
    for phase in self.params['dock']['phases']:
      self.stats_RL['u_K_'+phase] = \
        [self.dock_Es[-1][c]['RL'+phase][:,-1]/self.RT_SIMMIN \
          for c in range(self._dock_cycle)]

    # Interaction energies
    for phase in self.params['dock']['phases']:
      if (not 'Psi_'+phase in self.stats_RL):
        self.stats_RL['Psi_'+phase] = []
      for c in range(len(self.stats_RL['Psi_'+phase]), self._dock_cycle):
        self.stats_RL['Psi_'+phase].append(
          (self.dock_Es[-1][c]['RL'+phase][:,-1] - \
           self.dock_Es[-1][c]['L'+phase][:,-1] - \
           self.original_Es[0][0]['R'+phase][:,-1])/self.RT_SIMMIN)

    # Predict native pose
    if self.params['dock']['pose']==-1:
      (self.stats_RL['pose_inds'], self.stats_RL['scores']) = \
        self._get_pose_prediction('dock', self.stats_RL['equilibrated_cycle'][-1])

    # BPMF assuming receptor and complex solvation cancel
    self.B['MMTK_MBAR'] = [-self.f_L['cool_MBAR'][-1][-1] + \
      self.f_RL['grid_MBAR'][c][-1] for c in range(len(self.f_RL['grid_MBAR']))]

# %%
    for phase in self.params['dock']['phases']:
      for key in [phase+'_solv']:
        if not key in self.f_RL:
          self.f_RL[key] = []
      for method in ['min_Psi','mean_Psi','EXP','MBAR']:
        if not phase+'_'+method in self.B:
          self.B[phase+'_'+method] = []
      
      # Receptor solvation
      f_R_solv = self.original_Es[0][0]['R'+phase][:,-1]/self.RT_TARGET

      c = self._dock_cycle-1
      updated = set_updated_to_True(updated)
      extractCycles = range(self.stats_RL['equilibrated_cycle'][c], c+1)
      u_L = np.concatenate([\
        self.dock_Es[-1][c]['L'+phase][:,-1]/self.RT_SIMMIN \
        for c in extractCycles])
      u_RL = np.concatenate([\
        self.dock_Es[-1][c]['RL'+phase][:,-1]/self.RT_TARGET \
        for c in extractCycles])
      u_sampled = np.concatenate([\
        self.stats_RL['u_K_sampled'][c] for c in extractCycles])

      # From the full grid to the fully bound complex in phase
      du = u_RL - u_sampled
      min_du = min(du)
      weights = np.exp(-du+min_du)
      
      f_RL_solv = -np.log(np.exp(-du+min_du).mean()) + min_du - f_R_solv

      print phase, -self.f_L['cool_MBAR'][-1][-1], self.f_RL['grid_MBAR'][-1][-1], f_RL_solv,
      print (-self.f_L['cool_MBAR'][-1][-1] + self.f_RL['grid_MBAR'][-1][-1] + f_RL_solv)
# Out:
# NAMD_Gas 26.8651785233 -54.6289619079 [-30.30947703] [-58.07326042]
# NAMD_OBC 26.8651785233 -54.6289619079 [ 37.27515262] [ 9.51136924]
# OpenMM_OBC2 26.8651785233 -54.6289619079 [ 32.54919166] [ 4.78540827]

# %%
    for phase in self.params['dock']['phases']:
      for key in [phase+'_solv']:
        if not key in self.f_RL:
          self.f_RL[key] = []
      for method in ['min_Psi','mean_Psi','EXP','MBAR']:
        if not phase+'_'+method in self.B:
          self.B[phase+'_'+method] = []
      
      # Receptor solvation
      f_R_solv = self.original_Es[0][0]['R'+phase][:,-1]/self.RT_TARGET

      c = self._dock_cycle-1
      updated = set_updated_to_True(updated)
      extractCycles = range(self.stats_RL['equilibrated_cycle'][c], c+1)
      u_L = np.concatenate([\
        self.dock_Es[-1][c]['L'+phase][:,-1]/self.RT_SIMMIN \
        for c in extractCycles])
      u_RL = np.concatenate([\
        self.dock_Es[-1][c]['RL'+phase][:,-1]/self.RT_TARGET \
        for c in extractCycles])
      u_sampled = np.concatenate([\
        self.stats_RL['u_K_sampled'][c] for c in extractCycles])

      # From the full grid to the fully bound complex in phase
      du = np.concatenate([self.stats_RL['Psi_'+phase][c] - self.stats_RL['Psi_grid'][c]\
          for c in extractCycles])
      min_du = min(du)
      weights = np.exp(-du+min_du)
      
      f_RL_solv = -np.log(np.exp(-du+min_du).mean()) + min_du

      print phase, -self.f_L['cool_MBAR'][-1][-1], self.f_RL['grid_MBAR'][-1][-1], f_RL_solv,
      print (-self.f_L['cool_MBAR'][-1][-1] + self.f_RL['grid_MBAR'][-1][-1] + f_RL_solv)
# Out:
# NAMD_Gas 26.8651785233 -54.6289619079 -172.973371578 -200.737154962
# NAMD_OBC 26.8651785233 -54.6289619079 -19.647399043 -47.4111824276
# OpenMM_OBC2 26.8651785233 -54.6289619079 -33.9840090505 -61.7477924352

# %%
du - f_R_solv - self.f_L[phase+'_solv'][-1]
# Out:
# array([ 22414.43695149,  22416.07359335,  22420.94302855,  22422.34958552,
#         22407.975431  ,  22410.47637664])

# %%
phase
# Out:
# 'OpenMM_OBC2'

# %%
dPsi = np.concatenate([self.stats_RL['Psi_'+phase][c] - self.stats_RL['Psi_grid'][c]\
          for c in extractCycles])
print dPsi
# Out:
# [-29.23370375 -27.59706189 -22.72762669 -21.32106972 -35.69522424
#  -33.1942786 ]

# %%
dPsi
# Out:
# array([-29.23370375, -27.59706189, -22.72762669, -21.32106972,
#        -35.69522424, -33.1942786 ])

# %%
self.f_L
# Out:
# {'NAMD_Gas_solv': [147.08894034486499, 149.81176351219605, 147.67208012804448],
#  'NAMD_OBC_solv': [63.550591185846891, 63.301718646171871, 63.356829165029573],
#  'OpenMM_OBC2_solv': [72.624978681864889,
#   72.653582041074174,
#   72.679547876284701],
#  'cool_MBAR': [array([  0.        ,  -1.30439856,  -2.62252568,  -4.35914512,
#           -6.4937999 ,  -7.98487147,  -9.73305037, -12.06168879,
#          -14.38085287, -17.70503327, -21.02958783, -23.141317  , -26.97591581]),
#   array([  0.        ,  -1.34280878,  -2.69201452,  -4.45997187,
#           -6.62197829,  -8.12697864,  -9.88773176, -12.22868898,
#          -14.55643336, -17.88752653, -21.21269032, -23.32140163, -27.14370482]),
#   array([  0.        ,  -1.33735809,  -2.67916772,  -4.43452095,
#           -6.57687677,  -8.06579063,  -9.80573486, -12.11678088,
#          -14.41368988, -17.70160272, -20.98769921, -23.07475277, -26.86517852])],
#  'mean_NAMD_Gas': [52.996651645600807, 61.305495203390862, 58.743706400837347],
#  'mean_NAMD_OBC': [-25.470255132322905,
#   -25.297856397997073,
#   -24.161536512401025],
#  'mean_OpenMM_OBC2': [-16.835473259635712,
#   -15.94016518111798,
#   -14.916214967381217]}
