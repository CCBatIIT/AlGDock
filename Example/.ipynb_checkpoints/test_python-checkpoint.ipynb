# %%
import AlGDock.BindingPMF_plots
from AlGDock.BindingPMF_plots import *
import os, shutil, glob

phases = ['NAMD_Gas', 'NAMD_OBC']

self = AlGDock.BindingPMF_plots.BPMF_plots(\
  dir_dock='dock', dir_cool='cool',\
  ligand_tarball='prmtopcrd/ligand.tar.gz', \
  ligand_database='ligand.db', \
  forcefield='prmtopcrd/gaff.dat', \
  ligand_prmtop='ligand.prmtop', \
  ligand_inpcrd='ligand.trans.inpcrd', \
  ligand_mol2='ligand.mol2', \
  ligand_rb='ligand.rb', \
  receptor_tarball='prmtopcrd/receptor.tar.gz', \
  receptor_prmtop='receptor.prmtop', \
  receptor_inpcrd='receptor.trans.inpcrd', \
  receptor_fixed_atoms='receptor.pdb', \
  complex_tarball='prmtopcrd/complex.tar.gz', \
  complex_prmtop='complex.prmtop', \
  complex_inpcrd='complex.trans.inpcrd', \
  complex_fixed_atoms='complex.pdb', \
  score = 'prmtopcrd/anchor_and_grow_scored.mol2', \
  pose=-1, \
  rmsd=True, \
  dir_grid='grids', \
  protocol='Adaptive', cool_therm_speed=0.5, dock_therm_speed=0.5, \
  T_HIGH=600.0, T_SIMMIN=300.0, T_TARGET=300.0, \
  sampler='HMC', fraction_CD=0.5, CD_steps_per_trial=10, \
  MCMC_moves=1, \
  sampling_importance_resampling = True, \
  OBC_ligand = True, \
  seeds_per_state=10, steps_per_seed=200, darts_per_seed=0, \
  sweeps_per_cycle=25, attempts_per_sweep=100, \
  steps_per_sweep=100, darts_per_sweep=0, \
  cool_repX_cycles=3, dock_repX_cycles=4, \
  site='Sphere', site_center=[1.74395, 1.74395, 1.74395], \
  site_max_R=0.6, \
  site_density=10., \
  phases=phases, \
  cores=-1, \
  random_seed=-1, \
  max_time=240)
# Out:
# ###########
# # AlGDock #
# ###########
# Molecular docking with adaptively scaled alchemical interaction grids
#
# in /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.py
# last modified Fri Jan 13 16:39:34 2017
#
# using 4/4 available cores
# using random number seed of -1
#   no progress information for dock
#   no progress information for cool
#
# *** Directories ***
#   start: /Users/dminh/Installers/AlGDock-0.0.1/Example
#   cool: /Users/dminh/Installers/AlGDock-0.0.1/Example/cool
#   dock: /Users/dminh/Installers/AlGDock-0.0.1/Example/dock
#
# >>> Decompressing tarballs
# looking for:
#   complex.trans.inpcrd
#   complex.pdb
#   ligand.mol2
#   receptor.trans.inpcrd
#   ligand.trans.inpcrd
#   ligand.prmtop
#   ligand.db
#   receptor.pdb
#   complex.prmtop
#   ligand.rb
#   receptor.prmtop
#   and frcmod files
# reading prmtopcrd/complex.tar.gz
#   extracted complex.pdb
#   extracted complex.prmtop
#   extracted complex.trans.inpcrd
# reading prmtopcrd/receptor.tar.gz
#   extracted receptor.pdb
#   extracted receptor.prmtop
#   extracted receptor.trans.inpcrd
# reading prmtopcrd/ligand.tar.gz
#   extracted ligand.db
#   extracted /Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod
#   extracted ligand.mol2
#   extracted ligand.prmtop
#   extracted ligand.rb
#   extracted ligand.trans.inpcrd
#
# *** Files ***
#   ligand_database: dock/ligand.db
#   forcefield: prmtopcrd/gaff.dat
#   frcmodList: ['/Users/dminh/Installers/AlGDock-0.0.1/Example/dock/ligand.frcmod']
#   tarball:
#     L: prmtopcrd/ligand.tar.gz
#     R: prmtopcrd/receptor.tar.gz
#     RL: prmtopcrd/complex.tar.gz
#   prmtop:
#     L: dock/ligand.prmtop
#     R: dock/receptor.prmtop
#     RL: dock/complex.prmtop
#   inpcrd:
#     L: dock/ligand.trans.inpcrd
#     R: dock/receptor.trans.inpcrd
#     RL: dock/complex.trans.inpcrd
#   mol2:
#     L: dock/ligand.mol2
#   rb:
#     L: dock/ligand.rb
#   fixed_atoms:
#     R: dock/receptor.pdb
#     RL: dock/complex.pdb
#   grids:
#     LJr: grids/LJr.nc
#     LJa: grids/LJa.nc
#     ELE: grids/pbsa.nc
#   score: prmtopcrd/anchor_and_grow_scored.mol2
#   dir_cool: cool
#           DOES NOT EXIST
#
# >>> Setting up the simulation
#   considering a residue named "iga" as the ligand
#
# *** Simulation parameters and constants ***
#
# for cool:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 3
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 3.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   OBC_ligand: True
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#
# for dock:
#   protocol: Adaptive
#   therm_speed: 0.5
#   T_HIGH: 600.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 10
#   delta_t_TD: 4.0
#   delta_t: 3.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 4
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 25
#   attempts_per_sweep: 100
#   steps_per_sweep: 100
#   darts_per_sweep: 0
#   snaps_per_independent: 20.0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   OBC_ligand: True
#   keep_intermediate: False
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   site: Sphere
#   site_center: array([ 1.74395,  1.74395,  1.74395])
#   site_max_R: 0.6
#   site_density: 10.0
#   pose: -1
#   k_pose: 200.0
#   MCMC_moves: 1
#   rmsd: True

# %%
self.initial_cool()
# Out:
# >>> Initial warming
#     starting at Fri, 13 Jan 2017 16:59:29 +0000
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/simtk/openmm/app/internal/amber_file_parser.py:1010: UserWarning: Non-optimal GB parameters detected for GB model OBC2
#   'model %s' % gbmodel)
#   minimized 223 configurations in 23.65 s
#   the first 10 energies are:
#   -305.30, -301.76, -303.33, -276.99, -296.15, -294.98, -292.05, -300.81, -302.06, -303.02
#   keeping 223 minimized configurations out of
#   0 from xtal, 223 from dock6, 0 from initial docking, and 0 duplicated
#   ramped temperature from 20 to 300 K
#   changing energy from -308 to -223 kcal/mol
#
#   drew 10 configurations at 300 K in 0.18 s
#   Sampler 75/100=0.75 (0.4 s);
#   dt=3.00 fs; tL_tensor=2.025e-02
#
#   drew 10 configurations at 324 K in 0.24 s
#   Sampler 59/100=0.59 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.765e-02
#   the estimated repX acceptance rate is 0.76
#
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
#   drew 10 configurations at 357 K in 0.24 s
#   Sampler 71/100=0.71 (0.5 s);
#   dt=3.00 fs; tL_tensor=1.770e-02
#   the estimated repX acceptance rate is 0.73
#
#   drew 10 configurations at 392 K in 0.25 s
#   Sampler 58/100=0.58 (0.5 s);
#   dt=3.00 fs; tL_tensor=1.042e-02
#   the estimated repX acceptance rate is 0.75
#
#   drew 10 configurations at 449 K in 0.21 s
#   Sampler 60/100=0.60 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.570e-02
#   the estimated repX acceptance rate is 0.48
#
#   drew 10 configurations at 491 K in 0.17 s
#   Sampler 63/100=0.63 (0.4 s);
#   dt=3.00 fs; tL_tensor=1.514e-02
#   the estimated repX acceptance rate is 0.71
#
#   drew 10 configurations at 531 K in 0.22 s
#   Sampler 63/100=0.63 (0.5 s);
#   dt=3.00 fs; tL_tensor=1.089e-02
#   the estimated repX acceptance rate is 0.80
#
#   drew 10 configurations at 584 K in 0.21 s
#   Sampler 60/100=0.60 (0.4 s);
#   dt=3.00 fs; tL_tensor=8.425e-03
#   the estimated repX acceptance rate is 0.72
#
#   drew 10 configurations at 600 K in 0.22 s
#   Sampler 68/100=0.68 (0.5 s);
#   dt=3.00 fs; tL_tensor=9.000e-03
#   the estimated repX acceptance rate is 0.87
#
#   reversing replicas, samples, and protocol
#   wrote to cool_progress.pkl.gz
#   wrote to cool_data.pkl.gz
#
# Elapsed time for initial warming of 9 states: 28.36 s
# True

# %%
self.initial_cool()
# Out:
# [[array([[ -3.85041619e-02,   1.79113224e-01,  -2.72511692e-02],
#          [  1.12520991e-01,   3.87902903e-02,   9.45841414e-02],
#          [  6.48943123e-02,   2.77934073e-01,  -4.06982306e-02],
#          [  2.10345435e-01,   1.33588829e-01,   8.61990431e-02],
#          [ -1.27133577e-02,   6.17251471e-02,   4.23386597e-02],
#          [  1.91726065e-01,   2.50209146e-01,   2.11073587e-02],
#          [ -1.50284917e-01,  -2.93755100e-01,   1.87535690e-02],
#          [ -1.20562359e-01,  -4.12013771e-02,   6.25344298e-02],
#          [ -8.24893404e-02,  -1.62629270e-01,  -2.40348322e-02],
#          [ -1.39832556e-01,   1.91420365e-01,  -7.20640054e-02],
#          [ -1.93056832e-01,  -1.26610354e-01,  -2.12057757e-01],
#          [  2.57622978e-01,   4.33795107e-01,  -2.26053743e-03],
#          [  1.33511949e-01,  -4.38176655e-02,   1.53476917e-01],
#          [  4.53871786e-02,   3.67585982e-01,  -1.01864934e-01],
#          [  3.01267687e-01,   1.25645345e-01,   1.39394553e-01],
#          [ -1.29501560e-01,  -7.44814419e-02,   1.66910569e-01],
#          [ -2.17875486e-01,  -6.78435480e-03,   3.20452291e-02],
#          [  2.31826859e-02,  -1.78561347e-01,  -2.32725294e-04],
#          [ -4.10255874e-02,  -3.57483568e-02,  -1.88759807e-01],
#          [ -4.41320650e-02,  -2.00823109e-01,  -2.36384017e-01],
#          [ -9.09430344e-02,  -1.30240609e-01,  -1.77044498e-01],
#          [ -2.63097527e-01,  -3.21413507e-01,  -2.23911003e-03],
#          [ -7.73705875e-02,  -3.84003955e-01,   5.56720381e-02],
#          [  2.90139012e-01,   3.46288833e-01,   2.59968908e-02]]),
#   array([[ -3.57857522e-02,   1.61333462e-01,  -5.51630875e-02],
#          [  1.09867205e-01,   6.86003278e-02,   1.14062145e-01],
#          [  5.80365899e-02,   2.61022043e-01,  -7.75851038e-02],
#          [  2.04153424e-01,   1.65465945e-01,   9.21183645e-02],
#          [ -7.36590840e-03,   6.04756293e-02,   4.05654016e-02],
#          [  1.79569667e-01,   2.65010512e-01,   3.93605069e-05],
#          [ -1.34031281e-01,  -3.06462357e-01,   4.00046673e-02],
#          [ -1.10823415e-01,  -5.11391819e-02,   5.28256566e-02],
#          [ -7.28242361e-02,  -1.79580240e-01,  -2.58549293e-02],
#          [ -1.24409216e-01,   1.60069102e-01,  -1.21288907e-01],
#          [ -2.02914304e-01,  -1.67196743e-01,  -1.93843179e-01],
#          [  2.48761673e-01,   4.35484414e-01,  -8.03860080e-02],
#          [  1.25598794e-01,  -1.15126619e-02,   1.79682580e-01],
#          [  4.25335985e-02,   3.36334772e-01,  -1.57172513e-01],
#          [  2.96525403e-01,   1.69999473e-01,   1.48044777e-01],
#          [ -1.09390210e-01,  -8.32571436e-02,   1.53692423e-01],
#          [ -2.12674393e-01,  -2.45221924e-02,   4.61953301e-02],
#          [  3.32402809e-02,  -1.84868952e-01,  -9.12268446e-03],
#          [ -6.59436773e-02,  -6.84169961e-02,  -2.22541987e-01],
#          [ -5.50375641e-02,  -2.40490971e-01,  -2.37783669e-01],
#          [ -9.70473921e-02,  -1.61421171e-01,  -1.81733675e-01],
#          [ -2.43016089e-01,  -3.01446402e-01,   8.33637972e-02],
#          [ -5.89995986e-02,  -3.99915912e-01,   6.05776712e-02],
#          [  2.74017221e-01,   3.60681541e-01,  -1.82729532e-02]]),
#   array([[-0.07608351,  0.16935928, -0.03769923],
#          [ 0.09952789,  0.0877705 ,  0.095348  ],
#          [ 0.00512546,  0.2829438 , -0.06171224],
#          [ 0.17660357,  0.19775981,  0.07237064],
#          [-0.02776157,  0.07056634,  0.04772649],
#          [ 0.13625561,  0.29931254, -0.00578233],
#          [-0.08929928, -0.32189419,  0.05546566],
#          [-0.10007172, -0.06050329,  0.06801052],
#          [-0.04567352, -0.18227474, -0.00380946],
#          [-0.17799455,  0.15758255, -0.07656852],
#          [-0.16263967, -0.16986854, -0.18219466],
#          [ 0.15414959,  0.44709317, -0.11180973],
#          [ 0.13331519,  0.00460373,  0.15554664],
#          [-0.03523497,  0.35548735, -0.1392236 ],
#          [ 0.27966893,  0.18927364,  0.10451673],
#          [-0.10628089, -0.07852896,  0.174053  ],
#          [-0.21199935, -0.04648687,  0.05263616],
#          [ 0.06294276, -0.173988  ,  0.01281923],
#          [-0.02134761, -0.08966077, -0.18895858],
#          [-0.01460167, -0.25217619, -0.21210326],
#          [-0.05926247, -0.17494744, -0.1548105 ],
#          [-0.14567067, -0.39767659, -0.02415937],
#          [-0.03737121, -0.36564362,  0.15462987],
#          [ 0.20690544,  0.40237837, -0.04005093]]),
#   array([[-0.03534277,  0.15961732, -0.02676376],
#          [ 0.11657121,  0.05279847,  0.12262489],
#          [ 0.04857452,  0.27102053, -0.04509333],
#          [ 0.20416101,  0.15758685,  0.10244472],
#          [-0.00283143,  0.05600334,  0.05782303],
#          [ 0.17050746,  0.26472861,  0.02734545],
#          [-0.15884239, -0.2984928 ,  0.00085142],
#          [-0.104477  , -0.06170526,  0.06884651],
#          [-0.07146253, -0.1754079 , -0.02650436],
#          [-0.13288796,  0.15277183, -0.07068942],
#          [-0.15467131, -0.11287034, -0.20825585],
#          [ 0.21964782,  0.42538495, -0.06372972],
#          [ 0.13964776, -0.03259217,  0.18433443],
#          [ 0.01637162,  0.34895124, -0.11554846],
#          [ 0.30266145,  0.16310617,  0.1483974 ],
#          [-0.09891658, -0.09348865,  0.16691326],
#          [-0.20076492, -0.02764252,  0.03660559],
#          [ 0.03530391, -0.20102223, -0.01104536],
#          [ 0.01348689, -0.06055418, -0.19232935],
#          [-0.02204149, -0.20053211, -0.24993101],
#          [-0.05785968, -0.13249333, -0.18129098],
#          [-0.2736612 , -0.27839598,  0.03299721],
#          [-0.09647737, -0.40069123,  0.02857443],
#          [ 0.25900003,  0.3630953 ,  0.00208868]]),
#   array([[-0.02629042,  0.17434107, -0.01068599],
#          [ 0.15648308,  0.05781831,  0.09886085],
#          [ 0.05857808,  0.28547579, -0.030396  ],
#          [ 0.23636531,  0.17441972,  0.08069837],
#          [ 0.02870049,  0.05373971,  0.03083622],
#          [ 0.18919287,  0.28173032,  0.00976625],
#          [-0.12610452, -0.318459  ,  0.02081529],
#          [-0.06357858, -0.07012021,  0.06596254],
#          [-0.04563032, -0.19832951, -0.02844711],
#          [-0.12524304,  0.18177308, -0.04543802],
#          [-0.16186977, -0.10635003, -0.19237255],
#          [ 0.24098615,  0.46208753, -0.05298639],
#          [ 0.18984219, -0.02652248,  0.1597452 ],
#          [ 0.01221786,  0.37785257, -0.0677732 ],
#          [ 0.33771389,  0.17881835,  0.12376712],
#          [-0.03738269, -0.10976494,  0.16856531],
#          [-0.16403617, -0.04397219,  0.08023177],
#          [ 0.06132682, -0.22015893, -0.02649632],
#          [-0.00904924, -0.07070396, -0.19617292],
#          [-0.0587711 , -0.21706031, -0.23573445],
#          [-0.06800783, -0.14608614, -0.17010834],
#          [-0.20873365, -0.37121905, -0.05144569],
#          [-0.07793606, -0.38660499,  0.1070066 ],
#          [ 0.27523416,  0.39183931,  0.00470555]]),
#   array([[-0.05083004,  0.15917884, -0.02611837],
#          [ 0.13443969,  0.05534646,  0.09145379],
#          [ 0.02888656,  0.27035716, -0.04679942],
#          [ 0.2162867 ,  0.1687442 ,  0.06227541],
#          [-0.0008861 ,  0.05265684,  0.0531717 ],
#          [ 0.16513161,  0.27008453, -0.01209973],
#          [-0.14655966, -0.30275009,  0.03305064],
#          [-0.0858201 , -0.06992268,  0.07953739],
#          [-0.06121978, -0.17987285, -0.01273328],
#          [-0.1545435 ,  0.15999199, -0.06277942],
#          [-0.16367292, -0.09625338, -0.17395886],
#          [ 0.18557344,  0.47596256, -0.03821   ],
#          [ 0.17785983, -0.02868894,  0.13577462],
#          [-0.01479443,  0.35677838, -0.09861051],
#          [ 0.32037029,  0.17984388,  0.09725468],
#          [-0.06768181, -0.10165184,  0.17698825],
#          [-0.19316833, -0.04259891,  0.06844958],
#          [ 0.04558669, -0.21175797,  0.0037249 ],
#          [ 0.00129712, -0.07933934, -0.19570324],
#          [-0.06356951, -0.22951184, -0.22247241],
#          [-0.06997109, -0.14706415, -0.16348995],
#          [-0.26785243, -0.29578247,  0.03492191],
#          [-0.07733915, -0.39928914,  0.05320274],
#          [ 0.23402383,  0.38699145, -0.01550526]]),
#   array([[-0.04416268,  0.15936932, -0.02094171],
#          [ 0.14735965,  0.05010938,  0.08527167],
#          [ 0.03695766,  0.26715685, -0.0573261 ],
#          [ 0.2287232 ,  0.14737153,  0.04035386],
#          [ 0.0071763 ,  0.05659631,  0.05763449],
#          [ 0.17262567,  0.25961825, -0.02363625],
#          [-0.1374771 , -0.29367615,  0.0508774 ],
#          [-0.08969454, -0.05352751,  0.09312705],
#          [-0.07883376, -0.16567797, -0.00735624],
#          [-0.15186533,  0.17246194, -0.0346452 ],
#          [-0.23102668, -0.11139759, -0.15224671],
#          [ 0.2288846 ,  0.43038583, -0.10081203],
#          [ 0.17443443, -0.04026857,  0.14444698],
#          [-0.00239291,  0.35019398, -0.11654914],
#          [ 0.33576146,  0.14214779,  0.05440225],
#          [-0.06848771, -0.08608745,  0.19724826],
#          [-0.19069017, -0.02667078,  0.0878494 ],
#          [ 0.02898363, -0.17662658, -0.0125852 ],
#          [-0.08167983, -0.04359074, -0.19068668],
#          [-0.10384726, -0.20000514, -0.22488706],
#          [-0.12569464, -0.12918647, -0.15450446],
#          [-0.25765207, -0.31052433,  0.04978588],
#          [-0.06135306, -0.37320433,  0.09907686],
#          [ 0.26606069,  0.34874882, -0.069241  ]]),
#   array([[-0.04225276,  0.16713429, -0.06117323],
#          [ 0.10286521,  0.06050126,  0.11195957],
#          [ 0.05546668,  0.26138539, -0.07882211],
#          [ 0.19754027,  0.16582447,  0.09662483],
#          [-0.01882254,  0.06976556,  0.03769321],
#          [ 0.17443384,  0.25905152, -0.00427547],
#          [-0.1275592 , -0.30024818,  0.04823708],
#          [-0.11243691, -0.04481288,  0.06117545],
#          [-0.06601685, -0.17504497, -0.01321431],
#          [-0.13481112,  0.16382463, -0.1183712 ],
#          [-0.17528219, -0.11360513, -0.18608805],
#          [ 0.21146034,  0.44031431, -0.05935287],
#          [ 0.12526014, -0.01418293,  0.18736618],
#          [ 0.03557218,  0.33598351, -0.15262288],
#          [ 0.28797551,  0.18218704,  0.16265995],
#          [-0.10603605, -0.07519275,  0.1723828 ],
#          [-0.21037184, -0.02083   ,  0.03321111],
#          [ 0.03878048, -0.17365187,  0.00918402],
#          [-0.02854372, -0.07359664, -0.20523998],
#          [-0.07477555, -0.23318182, -0.22100731],
#          [-0.081666  , -0.15116655, -0.16357464],
#          [-0.24932573, -0.3196113 ,  0.04419258],
#          [-0.05203085, -0.38928113,  0.08644731],
#          [ 0.25985945,  0.36363385, -0.01909621]]),
#   array([[-0.03351472,  0.14720055, -0.04387784],
#          [ 0.13304487,  0.07486134,  0.1155204 ],
#          [ 0.03771969,  0.2609746 , -0.08066695],
#          [ 0.20756137,  0.18605104,  0.08283722],
#          [ 0.01304101,  0.0513075 ,  0.04703863],
#          [ 0.16183862,  0.27001833, -0.01839626],
#          [-0.16837807, -0.29783458,  0.0419378 ],
#          [-0.0691683 , -0.06976139,  0.08110295],
#          [-0.06317148, -0.19490035, -0.00705879],
#          [-0.13093597,  0.14959011, -0.08958686],
#          [-0.1392321 , -0.0901361 , -0.17392244],
#          [ 0.21525402,  0.43147543, -0.12217012],
#          [ 0.18831023,  0.00744674,  0.18427711],
#          [ 0.00441848,  0.33360326, -0.15271651],
#          [ 0.3026244 ,  0.21234139,  0.13338786],
#          [-0.0520109 , -0.09420029,  0.1891421 ],
#          [-0.16333855, -0.03212419,  0.07949638],
#          [ 0.03496741, -0.24182334,  0.01727068],
#          [ 0.01710913, -0.09984362, -0.1829412 ],
#          [-0.07627915, -0.24347461, -0.22208822],
#          [-0.06490582, -0.15793602, -0.15738103],
#          [-0.28716215, -0.27524738,  0.01672789],
#          [-0.12803451, -0.39343949,  0.10764197],
#          [ 0.24535843,  0.38252521, -0.04522507]]),
#   array([[-0.04577755,  0.18630316, -0.00572428],
#          [ 0.12743695,  0.03867802,  0.06152587],
#          [ 0.04675475,  0.29483818, -0.0124027 ],
#          [ 0.2212527 ,  0.13884429,  0.05173365],
#          [-0.00582082,  0.0584147 ,  0.03185246],
#          [ 0.17860045,  0.26836352,  0.02248904],
#          [-0.16067151, -0.28884472,  0.0277044 ],
#          [-0.1106686 , -0.05044981,  0.05484516],
#          [-0.07143013, -0.1762832 , -0.01712831],
#          [-0.15502234,  0.20092981, -0.01739624],
#          [-0.14123358, -0.1373842 , -0.21634134],
#          [ 0.20758285,  0.45019208, -0.02169731],
#          [ 0.1667374 , -0.05763976,  0.09744074],
#          [ 0.0191912 ,  0.39618741, -0.03415685],
#          [ 0.3237665 ,  0.12064601,  0.07597277],
#          [-0.11800984, -0.07779416,  0.15952646],
#          [-0.21432955, -0.01476906,  0.03190655],
#          [ 0.03025622, -0.20909659,  0.01770668],
#          [ 0.01793727, -0.09572265, -0.20716187],
#          [-0.03011266, -0.26052562, -0.21346129],
#          [-0.05183706, -0.16760524, -0.17039988],
#          [-0.26907132, -0.30123334, -0.02050289],
#          [-0.11300793, -0.37460815,  0.09336491],
#          [ 0.259478  ,  0.37218178,  0.01656056]])]]

# %%
self.random_dock()
# Out:
# 1
