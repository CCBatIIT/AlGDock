# %%
import AlGDock.BindingPMF_plots
from AlGDock.BindingPMF_plots import *
import os, shutil, glob

phases = ['NAMD_Gas', 'NAMD_OBC']

self = AlGDock.BindingPMF_plots.BPMF_plots(\
  dir_dock='dock', dir_cool='cool',\
  ligand_database='prmtopcrd/ligand.db', \
  forcefield='prmtopcrd/gaff2.dat', \
  ligand_prmtop='prmtopcrd/ligand.prmtop', \
  ligand_inpcrd='prmtopcrd/ligand.trans.inpcrd', \
  ligand_mol2='prmtopcrd/ligand.mol2', \
  ligand_rb='prmtopcrd/ligand.rb', \
  receptor_prmtop='prmtopcrd/receptor.prmtop', \
  receptor_inpcrd='prmtopcrd/receptor.trans.inpcrd', \
  receptor_fixed_atoms='prmtopcrd/receptor.pdb', \
  complex_prmtop='prmtopcrd/complex.prmtop', \
  complex_inpcrd='prmtopcrd/complex.trans.inpcrd', \
  complex_fixed_atoms='prmtopcrd/complex.pdb', \
  score = 'prmtopcrd/xtal_plus_dock6_scored.mol2', \
  temperature_scaling = 'Quadratic', \
  pose = -1, \
  rmsd=True, \
  dir_grid='grids', \
  protocol='Adaptive', cool_therm_speed=25.0, dock_therm_speed=0.25, \
  T_HIGH=450.0, T_SIMMIN=300.0, T_TARGET=300.0, \
  sampler='HMC', \
  MCMC_moves=1, \
  sampling_importance_resampling = True, \
  solvation = 'Full', \
  seeds_per_state=10, steps_per_seed=200, darts_per_seed=0, \
  sweeps_per_cycle=50, snaps_per_cycle=20, attempts_per_sweep=100, \
  steps_per_sweep=50, darts_per_sweep=0, \
  cool_repX_cycles=3, dock_repX_cycles=4, \
  site='Sphere', site_center=[1.7416, 1.7416, 1.7416], \
  site_max_R=1.0, \
  site_density=10., \
  phases=phases, \
  cores=-1, \
  random_seed=-1, \
  max_time=240, \
  keep_intermediate=True)
# Out:
# ###########
# # AlGDock #
# ###########
# Molecular docking with adaptively scaled alchemical interaction grids
#
# in /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.py
# last modified Sat Jul 29 11:35:50 2017
#
# using 4/4 available cores
# using random number seed of -1
#   no progress information for dock
#   no progress information for cool
#
# *** Directories ***
#   start: /Users/dminh/Installers/AlGDock-0.0.1/Example
#   cool: /Users/dminh/Installers/AlGDock-0.0.1/Example/cool
#   dock: /Users/dminh/Installers/AlGDock-0.0.1/Example/dock
#
# *** Files ***
#   ligand_database: prmtopcrd/ligand.db
#   forcefield: ../Data/gaff2.dat
#   frcmodList: ['/Users/dminh/Installers/AlGDock-0.0.1/Example/prmtopcrd/ligand.frcmod']
#   prmtop:
#     L: prmtopcrd/ligand.prmtop
#     R: prmtopcrd/receptor.prmtop
#     RL: prmtopcrd/complex.prmtop
#   inpcrd:
#     L: prmtopcrd/ligand.trans.inpcrd
#     R: prmtopcrd/receptor.trans.inpcrd
#     RL: prmtopcrd/complex.trans.inpcrd
#   mol2:
#     L: prmtopcrd/ligand.mol2
#   fixed_atoms:
#     R: prmtopcrd/receptor.pdb
#     RL: prmtopcrd/complex.pdb
#   grids:
#     LJr: grids/LJr.nc
#     LJa: grids/LJa.nc
#     ELE: grids/pbsa.nc
#     desolv: grids/desolv.nc
#   score: prmtopcrd/xtal_plus_dock6_scored.mol2
#   dir_cool: cool
#           DOES NOT EXIST
#
# ligand residue name: iga
#
# *** Simulation parameters and constants ***
#
# for cool:
#   protocol: Adaptive
#   therm_speed: 25.0
#   T_HIGH: 450.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 5
#   delta_t: 4.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 3
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 50
#   snaps_per_cycle: 20
#   attempts_per_sweep: 100
#   steps_per_sweep: 50
#   darts_per_sweep: 0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: True
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   delta_t_CD: 4.0
#
# for dock:
#   protocol: Adaptive
#   therm_speed: 0.25
#   T_HIGH: 450.0
#   T_SIMMIN: 300.0
#   T_TARGET: 300.0
#   H_mass: 4.0
#   fraction_CD: 0.5
#   CD_steps_per_trial: 5
#   delta_t: 4.0
#   sampler: HMC
#   steps_per_seed: 200
#   seeds_per_state: 10
#   darts_per_seed: 0
#   repX_cycles: 4
#   min_repX_acc: 0.4
#   sweeps_per_cycle: 50
#   snaps_per_cycle: 20
#   attempts_per_sweep: 100
#   steps_per_sweep: 50
#   darts_per_sweep: 0
#   phases: ['NAMD_Gas', 'NAMD_OBC']
#   sampling_importance_resampling: True
#   solvation: Full
#   keep_intermediate: True
#   GMC_attempts: 0
#   GMC_tors_threshold: 0.0
#   temperature_scaling: Quadratic
#   site: Sphere
#   site_center: array([ 1.7416,  1.7416,  1.7416])
#   site_max_R: 1.0
#   site_density: 10.0
#   pose: -1
#   k_pose: 1000.0
#   MCMC_moves: 1
#   rmsd: True
#   delta_t_CD: 4.0

# %%
self._run('all')
# Out:
# >>> Initial warming, starting at Sat, 29 Jul 2017 11:36:07
#
#   minimized 693 configurations in 1:1.51
#   the first 10 energies are:
#   -300.19, -295.78, -299.43, -297.72, -294.37, -289.34, -293.65, -284.60, -283.88, -291.62
#   keeping 693 minimized configurations out of
#   0 from xtal, 693 from dock6, 0 from initial docking, and 0 duplicated
#
#   ramped temperature from 20 to 300 K in 50.06 s, changing energy from -301 to -222 kcal/mol
#   at 300 K in 0.22 s: Sampler 17/40=0.42 (0.4 s);
#     dt=4.00 fs; tL_tensor=3.153e+00
#   at 307 K in 0.17 s: Sampler 24/40=0.60 (0.4 s);
#     dt=4.00 fs; tL_tensor=3.09e+00; <acc>=0.99
#   at 316 K in 0.58 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=2.19e+00; <acc>=0.94
#   at 328 K in 0.40 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.75 fs; tL_tensor=2.24e+00; <acc>=0.84
#   at 340 K in 0.50 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=2.90e+00; <acc>=0.90
#   at 349 K in 0.33 s: Sampler 19/40=0.47 (0.3 s);
#     dt=3.75 fs; tL_tensor=2.81e+00; <acc>=0.90
#   at 359 K in 0.32 s: Sampler 19/40=0.47 (0.4 s);
#     dt=3.75 fs; tL_tensor=1.98e+00; <acc>=0.92
#   at 372 K in 0.32 s: Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=2.26e+00; <acc>=0.80
#   at 384 K in 0.18 s: Sampler 18/40=0.45 (0.3 s);
#     dt=4.00 fs; tL_tensor=1.66e+00; <acc>=0.98
#   at 400 K in 0.16 s: Sampler 18/40=0.45 (0.4 s);
#     dt=4.00 fs; tL_tensor=2.28e+00; <acc>=0.93
#   at 412 K in 0.55 s: Sampler 18/40=0.45 (0.3 s);
#     dt=3.50 fs; tL_tensor=2.13e+00; <acc>=0.88
#   at 424 K in 0.80 s: Sampler 21/40=0.53 (0.3 s);
#     dt=3.25 fs; tL_tensor=1.26e+00; <acc>=0.96
#   at 445 K in 0.53 s: Sampler 18/40=0.45 (0.4 s);
#     dt=3.50 fs; tL_tensor=3.38e+00; <acc>=0.72
#   at 450 K in 0.91 s: Sampler 24/40=0.60 (0.4 s);
#     dt=3.25 fs; tL_tensor=2.16e+00; <acc>=0.98
#   reversing replicas, samples, and protocol
#   saved cool progress and data
#
# Elapsed time for initial warming of 14 states: 1:59.25
#
# >>> Replica exchange for cooling, starting at Sat, 29 Jul 2017 11:38:06
#
#   completed cycle 1 in 4.98 s
#   Sampler 284/700=0.41 (8.1 s); repX t 1501346291.9 s
#   saved cool progress and data
#
#   calculated cooling free energy of -26.93 RT using cycles 0 to 0
#   calculated cooling free energy of -27.00 RT using cycles 1 to 1
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/scipy/optimize/minpack.py:237: RuntimeWarning: xtol=0.000000 is too small, no further improvement in the approximate
#   solution is possible.
#   warnings.warn(msg, RuntimeWarning)
#   completed cycle 2 in 4.31 s
#   Sampler 288/700=0.41 (7.5 s); repX t 1501346298.4 s
#   saved cool progress and data
#
#   calculated cooling free energy of -26.76 RT using cycles 1 to 2
#
# Elapsed time for 2 cycles of replica exchange was 14.39 s
#
# >>> Postprocessing, starting at Sat, 29 Jul 2017 11:38:21
#
#   postprocessed cool, state 13, cycle 0, LNAMD_Gas in 0.25 s
#   postprocessed cool, state 13, cycle 0, LNAMD_OBC in 0.25 s
#   postprocessed cool, state 13, cycle 1, LNAMD_Gas in 0.26 s
#   postprocessed cool, state 13, cycle 1, LNAMD_OBC in 0.25 s
#   postprocessed cool, state 13, cycle 2, LNAMD_Gas in 0.18 s
#   postprocessed cool, state 13, cycle 2, LNAMD_OBC in 0.18 s
#   an average of 0.015716 s per LNAMD_OBC snapshot
#   an average of 0.015614 s per LNAMD_Gas snapshot
#   saved cool progress and data
#
# Elapsed time for postprocessing was 3.35 s
#
# >>> Ligand free energy calculations, starting at Sat, 29 Jul 2017 11:38:24
#
#   calculated NAMD_Gas solvation free energy of 141.81 RT using cycles 0 to 0
#   calculated NAMD_Gas solvation free energy of 147.58 RT using cycles 1 to 1
#   calculated NAMD_Gas solvation free energy of 146.54 RT using cycles 1 to 2
#   calculated NAMD_OBC solvation free energy of 63.676 RT using cycles 0 to 0
#   calculated NAMD_OBC solvation free energy of 63.314 RT using cycles 1 to 1
#   calculated NAMD_OBC solvation free energy of 63.357 RT using cycles 1 to 2
#   wrote to f_L.pkl.gz
#
# Elapsed time for free energy calculation: 0.04 s
#
# >>> Initial docking, starting at Sat, 29 Jul 2017 11:38:24
#
#   LJr grid loaded from LJr.nc in 0.46 s
#   LJa grid loaded from LJa.nc in 0.31 s
#   ELE grid loaded from pbsa.nc in 0.03 s
#   minimized 50 configurations in 5.37 s
#   the first 10 energies are:
#   -440.89, -374.84, -365.23, -368.53, -365.13, -372.59, -362.14, -357.04, -359.98, -366.75
#   keeping 50 minimized configurations out of
#   0 from xtal, 693 from dock6, 0 from initial docking, and 0 duplicated
#
#   ramped temperature from 20 to 300 K in 1:13.56, changing energy from -441 to -368 kcal/mol
#   sLJr grid loaded from LJr.nc in 0.33 s
#   sELE grid loaded from pbsa.nc in 0.03 s
#
#   at a=1.000e+00 in 1:20.71: Sampler 18/40=0.45 (0.4 s);
#     dt=3.25 fs, tL_tensor=3.868e+01
#   at a=9.935e-01 in 0.71 s: Sampler 18/40=0.45 (0.4 s);
#     dt=3.25 fs; tL_tensor=3.118e+01; <acc>=0.90
#   at a=9.853e-01 in 0.69 s: Sampler 20/40=0.50 (0.4 s);
#     dt=3.25 fs; tL_tensor=2.493e+01; <acc>=0.95
#   at a=9.749e-01 in 0.54 s: Sampler 22/40=0.55 (0.4 s);
#     dt=3.25 fs; tL_tensor=3.253e+01; <acc>=0.90
#   at a=9.670e-01 in 0.52 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.50 fs; tL_tensor=2.072e+01; <acc>=0.92
#   at a=9.545e-01 in 0.51 s: Sampler 19/40=0.47 (0.4 s);
#     dt=3.50 fs; tL_tensor=3.079e+01; <acc>=0.90
#   at a=9.460e-01 in 0.36 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.50 fs; tL_tensor=3.061e+01; <acc>=0.97
#   at a=9.376e-01 in 0.34 s: Sampler 20/40=0.50 (0.4 s);
#     dt=3.75 fs; tL_tensor=2.965e+01; <acc>=0.92
#   at a=9.289e-01 in 0.51 s: Sampler 18/40=0.45 (0.4 s);
#     dt=3.75 fs; tL_tensor=2.847e+01; <acc>=0.97
#   at a=9.198e-01 in 0.69 s: Sampler 19/40=0.47 (0.4 s);
#     dt=3.50 fs; tL_tensor=2.573e+01; <acc>=0.93
#   at a=9.098e-01 in 0.36 s: Sampler 19/40=0.47 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.692e+01; <acc>=0.95
#   at a=8.944e-01 in 0.52 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.75 fs; tL_tensor=2.213e+01; <acc>=0.93
#   at a=8.825e-01 in 0.70 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.978e+01; <acc>=0.92
#   at a=8.693e-01 in 0.68 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.492e+01; <acc>=0.93
#   at a=8.516e-01 in 0.53 s: Sampler 18/40=0.45 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.695e+01; <acc>=0.95
#   at a=8.359e-01 in 0.66 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.531e+01; <acc>=0.90
#   at a=8.186e-01 in 0.83 s: Sampler 21/40=0.53 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.751e+01; <acc>=0.99
#   at a=8.033e-01 in 0.84 s: Sampler 22/40=0.55 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.254e+01; <acc>=0.94
#   at a=7.822e-01 in 0.78 s: Sampler 16/40=0.40 (0.4 s);
#     dt=3.25 fs; tL_tensor=1.317e+01; <acc>=0.91
#   at a=7.616e-01 in 0.43 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.25 fs; tL_tensor=8.402e+00; <acc>=0.93
#   at a=7.294e-01 in 0.69 s: Sampler 17/40=0.42 (0.5 s);
#     dt=3.75 fs; tL_tensor=9.210e+00; <acc>=0.93
#   at a=6.983e-01 in 0.55 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=6.651e+00; <acc>=0.97
#   at a=6.551e-01 in 0.88 s: Sampler 20/40=0.50 (0.4 s);
#     dt=3.50 fs; tL_tensor=9.556e+00; <acc>=0.90
#   at a=6.227e-01 in 0.44 s: Sampler 16/40=0.40 (0.5 s);
#     dt=3.25 fs; tL_tensor=7.384e+00; <acc>=0.96
#   at a=5.816e-01 in 0.75 s: Sampler 22/40=0.55 (0.4 s);
#     dt=3.75 fs; tL_tensor=5.743e+00; <acc>=0.94
#   at a=5.316e-01 in 0.68 s: Sampler 17/40=0.42 (0.3 s);
#     dt=3.25 fs; tL_tensor=5.026e+00; <acc>=0.97
#   at a=4.816e-01 in 0.34 s: Sampler 17/40=0.42 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.583e+00; <acc>=1.00
#   rejected past state with high estimated acceptance rate
#   at a=4.316e-01 in 0.65 s: Sampler 23/40=0.57 (0.3 s);
#     dt=3.75 fs; tL_tensor=2.527e+00; <acc>=0.98
#   at a=3.816e-01 in 0.50 s: Sampler 22/40=0.55 (0.4 s);
#     dt=3.25 fs; tL_tensor=3.644e+00; <acc>=0.95
#   at a=3.316e-01 in 0.66 s: Sampler 16/40=0.40 (0.3 s);
#     dt=3.50 fs; tL_tensor=4.364e+00; <acc>=0.93
#   at a=2.849e-01 in 0.72 s: Sampler 19/40=0.47 (0.3 s);
#     dt=3.25 fs; tL_tensor=6.151e+00; <acc>=0.90
#   at a=2.508e-01 in 1.01 s: Sampler 22/40=0.55 (0.4 s);
#     dt=3.25 fs; tL_tensor=8.285e+00; <acc>=0.84
#   at a=2.238e-01 in 0.39 s: Sampler 20/40=0.50 (0.4 s);
#     dt=3.25 fs; tL_tensor=7.386e+00; <acc>=0.90
#   at a=1.925e-01 in 0.52 s: Sampler 17/40=0.42 (0.4 s);
#     dt=3.50 fs; tL_tensor=1.226e+01; <acc>=0.83
#   at a=1.738e-01 in 0.33 s: Sampler 16/40=0.40 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.456e+01; <acc>=0.86
#   at a=1.574e-01 in 0.47 s: Sampler 17/40=0.42 (0.3 s);
#     dt=3.75 fs; tL_tensor=8.482e+00; <acc>=0.93
#   at a=1.293e-01 in 0.63 s: Sampler 18/40=0.45 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.267e+01; <acc>=0.83
#   at a=1.109e-01 in 0.48 s: Sampler 20/40=0.50 (0.3 s);
#     dt=3.25 fs; tL_tensor=1.810e+01; <acc>=0.85
#   at a=9.761e-02 in 0.34 s: ExternalMC 1/50=0.02 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.305e+01; <acc>=0.94
#   at a=7.892e-02 in 0.18 s: ExternalMC 1/50=0.02 (0.0 s); Sampler 21/40=0.53 (0.3 s);
#     dt=3.75 fs; tL_tensor=1.825e+01; <acc>=0.76
#   at a=6.581e-02 in 0.66 s: ExternalMC 3/50=0.06 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=4.00 fs; tL_tensor=2.402e+01; <acc>=0.86
#   at a=5.568e-02 in 0.65 s: ExternalMC 3/50=0.06 (0.0 s); Sampler 23/40=0.57 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.469e+01; <acc>=0.82
#   at a=4.575e-02 in 0.18 s: ExternalMC 4/50=0.08 (0.0 s); Sampler 20/40=0.50 (0.3 s);
#     dt=3.25 fs; tL_tensor=2.454e+01; <acc>=0.79
#   at a=3.576e-02 in 0.49 s: ExternalMC 6/50=0.12 (0.0 s); Sampler 21/40=0.53 (0.3 s);
#     dt=4.00 fs; tL_tensor=3.276e+01; <acc>=0.83
#   at a=2.828e-02 in 0.51 s: ExternalMC 7/50=0.14 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=6.300e+01; <acc>=0.78
#   at a=2.436e-02 in 0.34 s: ExternalMC 4/50=0.08 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=5.979e+01; <acc>=0.84
#   at a=2.022e-02 in 0.48 s: ExternalMC 3/50=0.06 (0.0 s); Sampler 21/40=0.53 (0.3 s);
#     dt=3.75 fs; tL_tensor=6.526e+01; <acc>=0.83
#   at a=1.642e-02 in 0.33 s: ExternalMC 5/50=0.10 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=5.239e+01; <acc>=0.82
#   at a=1.169e-02 in 0.49 s: ExternalMC 6/50=0.12 (0.0 s); Sampler 23/40=0.57 (0.3 s);
#     dt=3.75 fs; tL_tensor=1.084e+02; <acc>=0.65
#   at a=9.402e-03 in 0.34 s: ExternalMC 6/50=0.12 (0.0 s); Sampler 16/40=0.40 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.635e+02; <acc>=0.87
#   at a=7.880e-03 in 0.49 s: ExternalMC 10/50=0.20 (0.0 s); Sampler 16/40=0.40 (0.3 s);
#     dt=3.75 fs; tL_tensor=8.188e+01; <acc>=0.89
#   at a=4.835e-03 in 0.34 s: ExternalMC 7/50=0.14 (0.0 s); Sampler 19/40=0.47 (0.3 s);
#     dt=3.50 fs; tL_tensor=1.909e+02; <acc>=0.49
#   at a=3.534e-03 in 0.33 s: ExternalMC 10/50=0.20 (0.0 s); Sampler 20/40=0.50 (0.3 s);
#     dt=3.75 fs; tL_tensor=3.146e+02; <acc>=0.87
#   at a=2.741e-03 in 0.47 s: ExternalMC 11/50=0.22 (0.1 s); Sampler 21/40=0.53 (0.7 s);
#     dt=3.75 fs; tL_tensor=2.192e+02; <acc>=0.93
#   at a=1.602e-03 in 0.96 s: ExternalMC 16/50=0.32 (0.0 s); Sampler 23/40=0.57 (0.3 s);
#     dt=3.75 fs; tL_tensor=6.086e+02; <acc>=0.54
#   at a=1.192e-03 in 0.29 s: ExternalMC 9/50=0.18 (0.0 s); Sampler 16/40=0.40 (0.6 s);
#     dt=3.25 fs; tL_tensor=4.428e+02; <acc>=0.91
#   at a=6.280e-04 in 0.24 s: ExternalMC 15/50=0.30 (0.0 s); Sampler 17/40=0.42 (0.4 s);
#     dt=4.00 fs; tL_tensor=2.035e+03; <acc>=0.67
#   at a=5.052e-04 in 0.49 s: ExternalMC 10/50=0.20 (0.0 s); Sampler 16/40=0.40 (0.6 s);
#     dt=4.00 fs; tL_tensor=1.057e+03; <acc>=0.92
#   at a=2.688e-04 in 0.45 s: ExternalMC 12/50=0.24 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=3.885e+03; <acc>=0.50
#   at a=2.044e-04 in 0.40 s: ExternalMC 11/50=0.22 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=2.825e+03; <acc>=0.87
#   at a=1.160e-04 in 0.18 s: ExternalMC 21/50=0.42 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=7.517e+03; <acc>=0.72
#   at a=8.272e-05 in 0.19 s: ExternalMC 18/50=0.36 (0.0 s); Sampler 18/40=0.45 (0.4 s);
#     dt=4.00 fs; tL_tensor=2.498e+04; <acc>=0.74
#   at a=7.271e-05 in 0.37 s: ExternalMC 19/50=0.38 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=4.00 fs; tL_tensor=2.402e+04; <acc>=0.85
#   at a=6.230e-05 in 0.51 s: ExternalMC 18/50=0.36 (0.0 s); Sampler 21/40=0.53 (0.3 s);
#     dt=3.75 fs; tL_tensor=1.106e+04; <acc>=0.98
#   at a=3.969e-05 in 0.66 s: ExternalMC 26/50=0.52 (0.0 s); Sampler 19/40=0.47 (0.3 s);
#     dt=3.50 fs; tL_tensor=2.959e+04; <acc>=0.71
#   at a=3.124e-05 in 0.50 s: ExternalMC 26/50=0.52 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.25 fs; tL_tensor=3.017e+04; <acc>=0.84
#   at a=2.295e-05 in 0.34 s: ExternalMC 27/50=0.54 (0.0 s); Sampler 21/40=0.53 (0.3 s);
#     dt=3.50 fs; tL_tensor=5.038e+04; <acc>=0.76
#   at a=1.799e-05 in 0.50 s: ExternalMC 27/50=0.54 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=5.671e+04; <acc>=0.84
#   at a=1.358e-05 in 0.49 s: ExternalMC 35/50=0.70 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.50 fs; tL_tensor=4.493e+04; <acc>=0.81
#   at a=8.020e-06 in 0.49 s: ExternalMC 43/50=0.86 (0.0 s); Sampler 27/40=0.68 (0.3 s);
#     dt=3.50 fs; tL_tensor=8.295e+04; <acc>=0.86
#   at a=5.006e-06 in 0.34 s: ExternalMC 42/50=0.84 (0.0 s); Sampler 17/40=0.42 (0.3 s);
#     dt=3.50 fs; tL_tensor=8.705e+04; <acc>=0.82
#   at a=2.134e-06 in 0.33 s: ExternalMC 50/50=1.00 (0.0 s); Sampler 16/40=0.40 (0.3 s);
#     dt=3.75 fs; tL_tensor=8.499e+04; <acc>=0.71
#   at a=0.000e+00 in 0.32 s: ExternalMC 50/50=1.00 (0.0 s); Sampler 18/40=0.45 (0.3 s);
#     dt=3.75 fs; tL_tensor=1.091e+05; <acc>=0.92
#   reversing replicas, samples, and protocol
#   saved dock progress and data
#
# Elapsed time for initial docking of 72 states: 1:59.01
#
# >>> Reinitializing replica exchange configurations
#   minimized 50 configurations in 5.17 s
#   the first 10 energies are:
#   -440.89, -374.84, -365.23, -368.53, -365.13, -372.59, -362.14, -357.04, -359.98, -366.75
#   keeping 72 minimized configurations out of
#   0 from xtal, 693 from dock6, 0 from initial docking, and 22 duplicated
#
# >>> Replica exchange for docking, starting at Sat, 29 Jul 2017 11:40:28
#
#   completed cycle 1 in 18.65 s
#   ExternalMC 4039/8750=0.46 (3.9 s); Sampler 942/3600=0.26 (39.5 s); repX t 1501346447.8 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -83.00 RT using cycles 1 to 1
#   wrote to f_RL.pkl.gz
#   inserted state between 0.72942 and 0.76157 at 0.74549
#   to improve acceptance rate from 0.14258 to 0.89809
#   inserted state between 0.74549 and 0.76157 at 0.75353
#   to improve acceptance rate from 0.23966 to 0.91647
#   saved dock progress and data
#
#   completed cycle 2 in 18.72 s
#   ExternalMC 3746/8750=0.43 (3.9 s); Sampler 1351/3700=0.37 (39.3 s); repX t 1501346480.8 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -79.72 RT using cycles 1 to 2
#   wrote to f_RL.pkl.gz
#   completed cycle 3 in 20.03 s
#   ExternalMC 3524/8750=0.40 (4.1 s); Sampler 1548/3700=0.42 (41.6 s); repX t 1501346512.5 s
#   saved dock progress and data
#
#   calculated grid scaling free energy of -76.96 RT using cycles 1 to 3
#   wrote to f_RL.pkl.gz
#   inserted state between 0.85165 and 0.86927 at 0.86046
#   to improve acceptance rate from 0.39445 to 0.82755
#   inserted state between 0.86046 and 0.86927 at 0.86486
#   to improve acceptance rate from 0.39563 to 0.81126
#   saved dock progress and data
#
#
# Elapsed time for 3 cycles of replica exchange was 2:15.73
#
# >>> Postprocessing, starting at Sat, 29 Jul 2017 11:42:44
#
#   postprocessed dock, state 75, cycle 0, LNAMD_Gas in 0.27 s
#   postprocessed dock, state 75, cycle 0, LNAMD_OBC in 0.27 s
#   postprocessed dock, state 75, cycle 1, LNAMD_OBC in 0.22 s
#   postprocessed dock, state 75, cycle 1, LNAMD_Gas in 0.22 s
#   postprocessed dock, state 75, cycle 2, LNAMD_Gas in 0.23 s
#   postprocessed dock, state 75, cycle 2, LNAMD_OBC in 0.23 s
#   postprocessed original, state 0, cycle 0, RNAMD_Gas in 0.96 s
#   postprocessed dock, state 75, cycle 3, LNAMD_Gas in 0.22 s
#   postprocessed dock, state 75, cycle 3, LNAMD_OBC in 0.24 s
#   postprocessed dock, state 75, cycle 0, RLNAMD_Gas in 1.27 s
#   postprocessed dock, state 75, cycle 1, RLNAMD_Gas in 1.69 s
#   postprocessed dock, state 75, cycle 2, RLNAMD_Gas in 1.41 s
#   postprocessed original, state 0, cycle 0, RNAMD_OBC in 4.63 s
#   postprocessed dock, state 75, cycle 3, RLNAMD_Gas in 1.51 s
#   postprocessed dock, state 75, cycle 0, RLNAMD_OBC in 38.18 s
#   postprocessed dock, state 75, cycle 1, RLNAMD_OBC in 1:8.22
#   postprocessed dock, state 75, cycle 2, RLNAMD_OBC in 1:7.90
#   postprocessed dock, state 75, cycle 3, RLNAMD_OBC in 1:7.01
#   an average of 0.089417 s per RLNAMD_Gas snapshot
#   an average of 4.6331 s per RNAMD_OBC snapshot
#   an average of 0.96049 s per RNAMD_Gas snapshot
#   an average of 0.015349 s per LNAMD_OBC snapshot
#   an average of 0.015133 s per LNAMD_Gas snapshot
#   an average of 3.4936 s per RLNAMD_OBC snapshot
#   saved dock progress and data
#   saved dock progress and data
#
# Elapsed time for postprocessing was 1:46.75
#   calculated grid scaling free energy of -61.82 RT using cycles 0 to 0
#   calculated NAMD_Gas binding PMF of -218.4 RT with cycles 0 to 0
#   calculated NAMD_Gas binding PMF of -229.13 RT with cycles 1 to 1
#   calculated NAMD_Gas binding PMF of -228.97 RT with cycles 1 to 2
#   calculated NAMD_Gas binding PMF of -228.62 RT with cycles 1 to 3
#   calculated NAMD_OBC binding PMF of -66.858 RT with cycles 0 to 0
#   calculated NAMD_OBC binding PMF of -77.391 RT with cycles 1 to 1
#   calculated NAMD_OBC binding PMF of -77.261 RT with cycles 1 to 2
#   calculated NAMD_OBC binding PMF of -76.92 RT with cycles 1 to 3
#   wrote to f_RL.pkl.gz
#
# Elapsed time for binding PMF estimation: 0.59 s
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be5e4e619e07> in <module>()
# ----> 1 self._run('all')
#
# /Users/dminh/Applications/miniconda2/envs/algdock/lib/python2.7/site-packages/AlGDock/BindingPMF.pyc in _run(self, run_type)
#     755         self._save(process)
#     756     if run_type is not None:
# --> 757       print "\nElapsed time for execution of %s: %s"%(kwargs['run_type'],
#     758         HMStime(time.time()-self.times['run']))
#     759
#
# NameError: global name 'kwargs' is not defined

# %%
self.start_times
# Out:
# {'BPMF': 1501346671.69262,
#  'ExternalMC': 4.120414733886719,
#  'Sampler': 41.6462287902832,
#  'SmartDarting': 0.0,
#  'T_ramp': 1501346310.941074,
#  'cool': 1501346167.599676,
#  'cool_repX_start': 1501346286.851506,
#  'cool_save': 1501346167.599677,
#  'cool_state': 1501346284.33735,
#  'dock_repX_start': 1501346428.935745,
#  'dock_save': 1501346304.686264,
#  'dock_state': 1501346421.877366,
#  'free energy': 1501346672.16564,
#  'grid_loading': 1501346385.357138,
#  'initial_dock': 1501346304.686262,
#  'max': 240,
#  'minimization': 1501346423.764095,
#  'postprocess': 1501346564.910905,
#  'repX': 1501346512.456405,
#  'repX cycle': 1501346492.430456,
#  'run': 1501346167.594245}

# %%
self.timings
